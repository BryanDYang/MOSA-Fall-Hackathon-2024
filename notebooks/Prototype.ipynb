# %% [markdown]
# <a href="https://colab.research.google.com/github/BryanDYang/MOSA-Fall-Hackathon-2024/blob/main/Prototype.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing libraries
import yfinance as yf
import pandas as pd
import numpy as np
import json

import requests
from datetime import datetime, timedelta
from textblob import TextBlob

# Visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Mount the google drive
prefix = '/content/drive'
from google.colab import drive
drive.mount(prefix, force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1. Research & Prototype using WRDS
#
# Goal: Begin with a small, manageable dataset and build a proof-of-concept (PoC) to validate the feasibility of the ESG-based recommendation approach. This step helps ensure that our planned APIs, data models, and algorithms are compatible, reliable, and useful before moving on to a larger-scale MVP.

# %%
# !pip install wrds

# %%
# Using the Wharton Research Data Services
import wrds
conn = wrds.Connection(wrds_username='bryanyang')
conn.create_pgpass_file()
# Out:
# Loading library list...
# Done
# Enter your WRDS username [bryanyang]:bryanyang
# Enter your password:··········

# %%
# Listing all the libraries of WRDS
conn.list_libraries().sort()
conn.list_libraries()
# Out:
# ['aha',
#  'aha_hcris_3years',
#  'aha_hcris_recent',
#  'aha_it_survey_3years',
#  'aha_it_survey_recent',
#  'aha_sample',
#  'ahasamp',
#  'audit',
#  'audit_acct_os',
#  'audit_audit_comp',
#  'audit_common',
#  'audit_corp_legal',
#  'audit_europe',
#  'audit_oia',
#  'audit_sedar',
#  'auditsmp',
#  'auditsmp_all',
#  'bank',
#  'bank_all',
#  'bank_premium',
#  'bank_premium_samp',
#  'banksamp',
#  'block',
#  'block_all',
#  'boardex',
#  'boardex_eur',
#  'boardex_na',
#  'boardex_row',
#  'boardex_trial',
#  'boardex_uk',
#  'boardsmp',
#  'bvd_amadeus_trial',
#  'bvd_bvdbankf_trial',
#  'bvd_orbis_trial',
#  'bvdsamp',
#  'calcbench_ap_ar',
#  'calcbench_business_combinations',
#  'calcbench_business_segments',
#  'calcbench_commitment_contingency',
#  'calcbench_common',
#  'calcbench_derivatives_hedging',
#  'calcbench_discontinued_ops',
#  'calcbench_equity_compensation',
#  'calcbench_equity_investments',
#  'calcbench_equity_repurchases',
#  'calcbench_fair_value',
#  'calcbench_goodwill',
#  'calcbench_income_tax',
#  'calcbench_inventory',
#  'calcbench_leases',
#  'calcbench_trial',
#  'calcbnch',
#  'cboe',
#  'cboe_all',
#  'cboe_eod',
#  'cboe_sample',
#  'cboesamp',
#  'centris',
#  'centris_all',
#  'ciq',
#  'ciq_capstrct',
#  'ciq_common',
#  'ciq_keydev',
#  'ciq_pplintel',
#  'ciq_ratings',
#  'ciq_transactions',
#  'ciq_transcripts',
#  'ciqsamp',
#  'ciqsamp_capstrct',
#  'ciqsamp_common',
#  'ciqsamp_keydev',
#  'ciqsamp_pplintel',
#  'ciqsamp_ratings',
#  'ciqsamp_transactions',
#  'ciqsamp_transcripts',
#  'cisdm',
#  'cisdmsmp',
#  'columnar',
#  'comp',
#  'comp_bank',
#  'comp_bank_daily',
#  'comp_emdb_daily',
#  'comp_emdb_monthly',
#  'comp_execucomp',
#  'comp_filings',
#  'comp_global',
#  'comp_global_daily',
#  'comp_na_annual_all',
#  'comp_na_daily_all',
#  'comp_na_daily_current',
#  'comp_na_monthly_all',
#  'comp_na_monthly_current',
#  'comp_ph',
#  'comp_pit',
#  'comp_ratings',
#  'comp_segments_hist',
#  'comp_segments_hist_daily',
#  'comp_snapshot',
#  'comp_urq',
#  'compa',
#  'compb',
#  'compdcur',
#  'compg',
#  'comph',
#  'compm',
#  'compmcur',
#  'compsamp',
#  'compsamp_all',
#  'compsamp_snapshot',
#  'compseg',
#  'compsnap',
#  'comscore',
#  'comscore_2002',
#  'comscore_2004',
#  'comscore_2006',
#  'comscore_2007',
#  'comscore_2008',
#  'comscore_2009',
#  'comscore_2010',
#  'comscore_2011',
#  'comscore_2012',
#  'comscore_2013',
#  'comscore_2014',
#  'comscore_2015',
#  'comscore_2016',
#  'comscore_2017',
#  'comscore_2018',
#  'comscore_2019',
#  'comscore_2020',
#  'comscore_2021',
#  'comscore_2022',
#  'comscore_2023',
#  'comscore_common',
#  'contrib',
#  'contrib_as_filed_financials',
#  'contrib_ceo_turnover',
#  'contrib_char_returns',
#  'contrib_corporate_culture',
#  'contrib_general',
#  'contrib_global_factor',
#  'contrib_green_returns',
#  'contrib_intangible_value',
#  'contrib_kpss',
#  'contrib_liva',
#  'crsp',
#  'crsp_a_ccm',
#  'crsp_a_indexes',
#  'crsp_a_stock',
#  'crsp_a_stock62',
#  'crsp_a_treasuries',
#  'crsp_a_ziman',
#  'crsp_m_ccm',
#  'crsp_m_indexes',
#  'crsp_m_stock',
#  'crsp_m_stock62',
#  'crsp_m_treasuries',
#  'crsp_m_ziman',
#  'crsp_q_ccm',
#  'crsp_q_indexes',
#  'crsp_q_indexhist',
#  'crsp_q_mi_hist',
#  'crsp_q_mutualfunds',
#  'crsp_q_stock',
#  'crsp_q_stock62',
#  'crsp_q_treasuries',
#  'crsp_q_ziman',
#  'crspm',
#  'crspq',
#  'crspsamp',
#  'crspsamp_all',
#  'crspsamp_mf',
#  'csmar',
#  'csmar_af',
#  'csmar_cd',
#  'csmar_cg',
#  'csmar_colc',
#  'csmar_financial',
#  'csmar_funds',
#  'csmar_hld',
#  'csmar_ini',
#  'csmar_ipo_a',
#  'csmar_ma',
#  'csmar_rs',
#  'csmar_trade',
#  'csmsamp_all',
#  'dealscan',
#  'djones',
#  'djones_all',
#  'dmef',
#  'dmef_all',
#  'doe',
#  'doe_all',
#  'emdb',
#  'estimize',
#  'estimize_estimates_consensus',
#  'etfg',
#  'etfg_analytics',
#  'etfg_constituents',
#  'etfg_fund_flow',
#  'etfg_industry',
#  'etfg_samp',
#  'etfgsamp',
#  'eurekahedge_sample',
#  'eursamp',
#  'eventus',
#  'evts_all',
#  'execcomp',
#  'factsamp_all',
#  'factsamp_revere',
#  'factset',
#  'factset_common',
#  'factset_ff_int',
#  'factset_ff_usc',
#  'factset_own',
#  'factset_revere_common',
#  'factset_revere_geo_rev',
#  'factset_revere_ind_class',
#  'factset_revere_supply_chain',
#  'ff',
#  'ff_all',
#  'fisd',
#  'fisd_common',
#  'fisd_fisd',
#  'fisd_naic',
#  'fisdsamp',
#  'fisdsamp_all',
#  'fjc',
#  'fjc_linking',
#  'fjc_litigation',
#  'frb',
#  'frb_all',
#  'fssamp',
#  'ftse',
#  'ftse_russell_us',
#  'ftsesamp',
#  'ftsesamp_russell_us',
#  'ginsight',
#  'ginsight_all',
#  'ginsight_basic',
#  'ginsight_common',
#  'gmi',
#  'gmi_all',
#  'gutenberg',
#  'hfr',
#  'hfr_academic_dead',
#  'hfr_academic_live',
#  'hfr_hfrdb',
#  'hfr_hfrdb_dead',
#  'hfrsamp',
#  'hfrsamp_hfrdb',
#  'ibes',
#  'ibeskpi',
#  'ibessamp_kpi',
#  'ifgr',
#  'ifgrsamp',
#  'ims',
#  'ims_hist_3yr_obp_premium',
#  'ims_hist_3yr_obp_standard_plus',
#  'ims_hist_5yr_obp_premium',
#  'ims_hist_5yr_obp_standard_plus',
#  'ims_hist_obp_premium',
#  'ims_hist_obp_standard',
#  'ims_hist_obp_standard_plus',
#  'ims_obp_premium',
#  'ims_obp_standard',
#  'ims_obp_standard_plus',
#  'ims_obp_trial',
#  'imssamp',
#  'infogroup_business_academic',
#  'infogroup_residential',
#  'infogroupsamp_business',
#  'infogroupsamp_residential',
#  'insdsamp',
#  'iri',
#  'iri_all',
#  'iss',
#  'iss_climate_core',
#  'iss_climate_emissions',
#  'iss_climate_energy',
#  'iss_climate_impact',
#  'iss_climate_physical_risk',
#  'iss_compensation_analytics',
#  'iss_compensation_peers',
#  'iss_directors_global',
#  'iss_incentive_lab',
#  'iss_incentive_lab_europe',
#  'iss_va_mf',
#  'iss_va_shareholder',
#  'iss_va_vote_global',
#  'iss_va_vote_us',
#  'issm',
#  'issm_nasd1987',
#  'issm_nasd1988',
#  'issm_nasd1989',
#  'issm_nasd1990',
#  'issm_nasd1991',
#  'issm_nasd1992',
#  'issm_nyam1983',
#  'issm_nyam1984',
#  'issm_nyam1985',
#  'issm_nyam1986',
#  'issm_nyam1987',
#  'issm_nyam1988',
#  'issm_nyam1989',
#  'issm_nyam1990',
#  'issm_nyam1991',
#  'issm_nyam1992',
#  'kld',
#  'kld_histall',
#  'kpisamp',
#  'ktmine',
#  'ktmine_corptree',
#  'ktmine_corptree_samp',
#  'ktmine_patents',
#  'ktmine_patents_samp',
#  'ktsamp',
#  'lspd',
#  'lspd_daily',
#  'lspd_monthly',
#  'lspdsamp',
#  'lspdsamp_all',
#  'lvnsamp',
#  'lvnsamp_all',
#  'macrofin',
#  'macrofin_comm_trade',
#  'markit',
#  'markit_cds',
#  'markit_cdxcomps',
#  'markit_cdxconst',
#  'markit_itraxxascomps',
#  'markit_itraxxasconst',
#  'markit_itraxxeucomps',
#  'markit_itraxxeuconst',
#  'markit_itraxxsocomps',
#  'markit_itraxxsoconst',
#  'markit_msf_analytics_bonds',
#  'markit_msf_analytics_eqty_amer',
#  'markit_msf_analytics_eqty_asia',
#  'markit_msf_analytics_eqty_euro',
#  'markit_msf_analytics_eqty_other',
#  'markit_msf_inst_bonds',
#  'markit_msf_inst_eqty_amer',
#  'markit_msf_inst_eqty_asia',
#  'markit_msf_inst_eqty_euro',
#  'markit_msf_inst_eqty_other',
#  'markit_red',
#  'mfl',
#  'mflinks_all',
#  'midas',
#  'morningstar_cisdm',
#  'morningstarsamp_cisdm',
#  'mrktsamp',
#  'mrktsamp_cds',
#  'mrktsamp_cdx',
#  'mrktsamp_msf',
#  'msci_esg',
#  'msci_esg_samp',
#  'msciesg',
#  'msciesmp',
#  'msfanly',
#  'msfinst',
#  'msrb',
#  'msrb_all',
#  'msrbsamp',
#  'msrbsamp_all',
#  'omtrial',
#  'optionm',
#  'optionm_all',
#  'optionm_europe',
#  'optionmsamp_europe',
#  'optionmsamp_us',
#  'otc',
#  'otc_endofday',
#  'pacap',
#  'pacap_indonesia',
#  'pacap_japan',
#  'pacap_korea',
#  'pacap_malaysia',
#  'pacap_singapore',
#  'pacap_taiwan',
#  'phlx',
#  'phlx_all',
#  'pitchbk',
#  'pitchbk_common',
#  'pitchbk_other_na',
#  'pitchbk_other_row',
#  'pitchbk_pe_na',
#  'pitchbk_pe_row',
#  'pitchbk_vc_na',
#  'pitchbk_vc_row',
#  'pitchsmp',
#  'ppubsamp',
#  'ppubsamp_d4d',
#  'ppubsamp_rx_checkup',
#  'preqin',
#  'preqin_cashflow',
#  'preqin_deals',
#  'preqin_gp',
#  'preqin_lp',
#  'preqin_pe',
#  'preqin_vc',
#  'preqsamp',
#  'preqsamp_all',
#  'public',
#  'public_all',
#  'pwt',
#  'pwt_all',
#  'ravenpack_common',
#  'ravenpack_dj',
#  'ravenpack_full',
#  'ravenpack_trial',
#  'ravenpack_web',
#  'rent',
#  'rent_all',
#  'reprisk',
#  'reprisk_common',
#  'reprisk_pm',
#  'reprisk_sample',
#  'reprisk_std',
#  'reprisk_v2',
#  'repsamp',
#  'revelio',
#  'revelio_common',
#  'revelio_individual',
#  'revelio_job_postings',
#  'revelio_samp',
#  'revelio_sentiment',
#  'revelio_workforce_dynamics',
#  'revere',
#  'revsamp',
#  'risk',
#  'risk_directors',
#  'risk_governance',
#  'risk_proposals',
#  'risk_votes',
#  'risksamp',
#  'risksamp_all',
#  'rpna',
#  'rpnasamp',
#  'rq_all',
#  'rstat',
#  'rstat_royalty',
#  'rstat_samp',
#  'rstatsmp',
#  'sdc',
#  'sdcsamp',
#  'sds',
#  'sds_rate_transparency',
#  'secsamp',
#  'secsamp_all',
#  'snapsamp',
#  'snl',
#  'snl_fundamentals',
#  'snlsamp',
#  'snlsamp_fig',
#  'sp_esg',
#  'sprat',
#  'sustain',
#  'sustainalytics_all',
#  'sustainalytics_na_only',
#  'sustainalyticssamp_all',
#  'sustsamp',
#  'taqm_2003',
#  'taqm_2004',
#  'taqm_2005',
#  'taqm_2006',
#  'taqm_2007',
#  'taqm_2008',
#  'taqm_2009',
#  'taqm_2010',
#  'taqm_2011',
#  'taqm_2012',
#  'taqm_2013',
#  'taqm_2014',
#  'taqm_2015',
#  'taqm_2016',
#  'taqm_2017',
#  'taqm_2018',
#  'taqm_2019',
#  'taqm_2020',
#  'taqm_2021',
#  'taqm_2022',
#  'taqm_2023',
#  'taqm_2024',
#  'taqmsamp',
#  'taqmsamp_all',
#  'taqmsec',
#  'taqsamp',
#  'taqsamp_all',
#  'tass',
#  'tfn',
#  'tfn_common',
#  'totalq',
#  'totalq_all',
#  'tr_13f',
#  'tr_common',
#  'tr_dandb_dmi_us',
#  'tr_dandb_wb_af',
#  'tr_dandb_wb_ap',
#  'tr_dandb_wb_eu',
#  'tr_dandb_wb_la',
#  'tr_dandb_wb_me',
#  'tr_dandb_wb_na',
#  'tr_dandb_wb_unknown',
#  'tr_dealscan',
#  'tr_ds_comds',
#  'tr_ds_econ',
#  'tr_ds_equities',
#  'tr_ds_fut',
#  'tr_esg',
#  'tr_ibes',
#  'tr_ibes_guidance',
#  'tr_ibes_iga',
#  'tr_ibeskpi',
#  'tr_insiders',
#  'tr_mutualfunds',
#  'tr_ownership',
#  'tr_sdc_joint_ventures',
#  'tr_sdc_ma',
#  'tr_sdc_municipals',
#  'tr_sdc_ni',
#  'tr_sdc_private_equity',
#  'tr_sdc_samples',
#  'tr_tass',
#  'tr_worldscope',
#  'trace',
#  'trace_enhanced',
#  'trace_standard',
#  'trcommon',
#  'trcstsmp',
#  'trdandb',
#  'trdbdmismp',
#  'trdbwbsmp',
#  'trdssamp',
#  'trdstrm',
#  'tresg',
#  'tresgsmp',
#  'trown',
#  'trsamp',
#  'trsamp_all',
#  'trsamp_db_dmi',
#  'trsamp_db_wb',
#  'trsamp_ds_eq',
#  'trsamp_dscom',
#  'trsamp_dsecon',
#  'trsamp_dsfut',
#  'trsamp_esg',
#  'trsamp_sdc_ma',
#  'trsamp_sdc_ni',
#  'trsamp_worldscope',
#  'trucost',
#  'trucost_carbon',
#  'trucost_common',
#  'trucost_environ',
#  'trucost_fossilfuel',
#  'trucost_paris',
#  'trucost_risk',
#  'trucost_samp',
#  'trucost_sector_ff',
#  'trucost_sector_revenue',
#  'trws',
#  'twoiq',
#  'twoiq_all',
#  'twoiq_samp',
#  'twoiqsmp',
#  'wappsamp',
#  'wenvsmp',
#  'wind',
#  'wind_ashare',
#  'wind_code',
#  'wmfsmp',
#  'wrds_environmental',
#  'wrds_environmental_samp',
#  'wrds_insiders',
#  'wrds_insiders_samp',
#  'wrds_lib_internal',
#  'wrds_mutualfund',
#  'wrds_mutualfund_samp',
#  'wrds_sec_search',
#  'wrdsapps',
#  'wrdsapps_backtest_basic',
#  'wrdsapps_backtest_plus',
#  'wrdsapps_bondret',
#  'wrdsapps_eushort',
#  'wrdsapps_evtstudy_int',
#  'wrdsapps_evtstudy_int_ginsight',
#  'wrdsapps_evtstudy_intraday_rav',
#  'wrdsapps_evtstudy_lr',
#  'wrdsapps_evtstudy_lr_ciq',
#  'wrdsapps_evtstudy_us',
#  'wrdsapps_finratio',
#  'wrdsapps_finratio_ccm',
#  'wrdsapps_finratio_ibes',
#  'wrdsapps_finratio_ibes_ccm',
#  'wrdsapps_link_comp_eushort',
#  'wrdsapps_link_crsp_bond',
#  'wrdsapps_link_crsp_comp_bdx',
#  'wrdsapps_link_crsp_factset',
#  'wrdsapps_link_crsp_ibes',
#  'wrdsapps_link_crsp_optionm',
#  'wrdsapps_link_crsp_taq',
#  'wrdsapps_link_crsp_taqm',
#  'wrdsapps_link_datastream_wscope',
#  'wrdsapps_link_dealscan_wscope',
#  'wrdsapps_link_supplychain',
#  'wrdsapps_link_trinsider_bdx',
#  'wrdsapps_patents',
#  'wrdsapps_plink_boardex_ciq',
#  'wrdsapps_plink_boardex_trinsider',
#  'wrdsapps_plink_boardex_twoiq',
#  'wrdsapps_plink_exec_boardex',
#  'wrdsapps_plink_exec_ciq',
#  'wrdsapps_plink_exec_trinsider',
#  'wrdsapps_plink_exec_twoiq',
#  'wrdsapps_plink_trinsider_ciq',
#  'wrdsapps_plink_trinsider_twoiq',
#  'wrdsapps_plink_twoiq_ciq',
#  'wrdsapps_subsidiary',
#  'wrdsapps_windices',
#  'wrdsappssamp_all',
#  'wrdsenv',
#  'wrdsinsd',
#  'wrdsmf',
#  'wrdssec',
#  'wrdssec_all',
#  'wrdssec_bow',
#  'wrdssec_common',
#  'wrdssec_insiders',
#  'wrdssec_midas',
#  'wrdssec_secsa',
#  'zacks',
#  'zacks_all',
#  'zacksamp',
#  'zacksamp_all']

# %%
# Exploring msci esg tables.
conn.list_tables(library='msci_esg')
# Out:
# ['msci_esg_dictionary', 'msci_esg_ratings']

# %%
# Extracting first 5 rows of msci_esg rating
msci_esg_dict = conn.get_table(library='msci_esg', table='msci_esg_dictionary', obs=5)
msci_esg_dict
# Out:
#    index esg_category    factor_name                  description  \
# 0      1        Other    Issuer Name                System factor
# 1      2  Issuer Data      Issuer Id                    Issuer Id
# 2      3        Other  Issuer Ticker                System factor
# 3      4  Issuer Data   Issuer CUSIP  Issuer CUSIP. System factor
# 4      5  Issuer Data   Issuer SEDOL  Issuer SEDOL. System factor
#
#    column_header              data_type  start_date
# 0    ISSUER_NAME  String [Example Text]  2007-01-01
# 1       ISSUERID  String [Example Text]  2007-01-01
# 2  ISSUER_TICKER  String [Example Text]  2007-01-01
# 3   ISSUER_CUSIP  String [Example Text]  2007-01-01
# 4   ISSUER_SEDOL  String [Example Text]  2007-01-01

# %%
# Extracting first 5 rows of msci_esg rating
msci_esg_rt = conn.get_table(library='msci_esg', table='msci_esg_ratings', obs=5)
msci_esg_rt
# Out:
#                               issuer_name            issuerid issuer_ticker  \
# 0  COBALTS Trust for Sprint Capital Notes  IID000000001789005          None
# 1  COBALTS Trust for Sprint Capital Notes  IID000000001789005          None
# 2  COBALTS Trust for Sprint Capital Notes  IID000000001789005          None
# 3  COBALTS Trust for Sprint Capital Notes  IID000000001789005          None
# 4  COBALTS Trust for Sprint Capital Notes  IID000000001789005          None
#
#   issuer_cusip issuer_sedol   issuer_isin issuer_cntry_domicile  as_of_date  \
# 0    19074VAA0         None  US19074VAA08                    US  2013-01-01
# 1    19074VAA0         None  US19074VAA08                    US  2013-02-01
# 2    19074VAA0         None  US19074VAA08                    US  2013-03-01
# 3    19074VAA0         None  US19074VAA08                    US  2013-10-01
# 4    19074VAA0         None  US19074VAA08                    US  2013-11-01
#
#                           iva_industry iva_rating_date  ...  \
# 0  Wireless Telecommunication Services      2012-02-01  ...
# 1  Wireless Telecommunication Services      2012-02-01  ...
# 2  Wireless Telecommunication Services      2012-02-01  ...
# 3  Wireless Telecommunication Services      2013-03-26  ...
# 4  Wireless Telecommunication Services      2013-03-26  ...
#
#   board_majority_ind_of_other_int board_majority_ind_other_int_sd  \
# 0                            None                            None
# 1                            None                            None
# 2                            None                            None
# 3                            None                            None
# 4                            None                            None
#
#   no_nom_committee no_nom_committee_sd nom_committee_chair_ind  \
# 0             None                None                    None
# 1             None                None                    None
# 2             None                None                    None
# 3             None                None                    None
# 4             None                None                    None
#
#   nom_committee_chair_ind_sd nom_committee_ind nom_committee_ind_sd  \
# 0                       None              None                 None
# 1                       None              None                 None
# 2                       None              None                 None
# 3                       None              None                 None
# 4                       None              None                 None
#
#   corp_behav_tax_transp_score extern_manage_co
# 0                        None             None
# 1                        None             None
# 2                        None             None
# 3                        None             None
# 4                        None             None
#
# [5 rows x 253 columns]

# %%
# Exploring msci esg tables.
conn.list_tables(library='msci_esg_samp')
# Out:
# ['msci_esg_expanded', 'msci_esg_ratings', 'msci_esg_summary']

# %%
# Exploring msci esg tables.
conn.list_tables(library='msciesg')
# Out:
# ['msci_esg_dictionary',
#  'msci_esg_expanded',
#  'msci_esg_ratings',
#  'msci_esg_summary']

# %%
# Extracting first 5 rows of msciesg expanded
msci_esg_exp = conn.get_table(library='msciesg', table='msci_esg_dictionary', obs=5)
msci_esg_exp
# Out:
#    index esg_category    factor_name                  description  \
# 0      1        Other    Issuer Name                System factor
# 1      2  Issuer Data      Issuer Id                    Issuer Id
# 2      3        Other  Issuer Ticker                System factor
# 3      4  Issuer Data   Issuer CUSIP  Issuer CUSIP. System factor
# 4      5  Issuer Data   Issuer SEDOL  Issuer SEDOL. System factor
#
#    column_header              data_type  start_date
# 0    ISSUER_NAME  String [Example Text]  2007-01-01
# 1       ISSUERID  String [Example Text]  2007-01-01
# 2  ISSUER_TICKER  String [Example Text]  2007-01-01
# 3   ISSUER_CUSIP  String [Example Text]  2007-01-01
# 4   ISSUER_SEDOL  String [Example Text]  2007-01-01

# %% [markdown]
# Strange that there are no tables called `msci_esg_expaneded` & `msci_esg_summary` within `msciesg` library

# %%
# Exploring sp esg tables.
conn.list_tables(library='sp_esg')
# Out:
# ['spgquestion', 'wrds_esg', 'wrds_esg_facts']

# %%
# Extrating first 5 rows of sp_esg question table
sp_esg_q = conn.get_table(library='sp_esg', table='spgquestion', obs=5)
sp_esg_q
# Out:
#   questionid                      questionname  \
# 0          1                     Absentee Rate
# 1          2  Absenteeism: Work-Related Stress
# 2          3        Access for Disabled People
# 3          4          Access Through Education
# 4          5       Access to Genetic Resources
#
#                                  questiondescription
# 0  Please indicate your company's absentee rate f...
# 1                                               None
# 2  Please briefly describe initiatives that your ...
# 3  Please briefly describe initiatives undertaken...
# 4  Do you have policies and standards regarding t...

# %%
# Extrating first 5 rows of sp_esg wrds_esg
sp_esg_wrds = conn.get_table(library='sp_esg', table='wrds_esg', obs=5)
sp_esg_wrds
# Out:
#                                 scoreid                      dimensionscoreid  \
# 0  5A1E6322-1057-42E2-BEBB-DED5A53D6884  BF23BB3C-1169-42C0-A1AD-41A1DC65CBFA
# 1  5A1E6322-1057-42E2-BEBB-DED5A53D6884  BF23BB3C-1169-42C0-A1AD-41A1DC65CBFA
# 2  5A1E6322-1057-42E2-BEBB-DED5A53D6884  BF23BB3C-1169-42C0-A1AD-41A1DC65CBFA
# 3  5A1E6322-1057-42E2-BEBB-DED5A53D6884  BF23BB3C-1169-42C0-A1AD-41A1DC65CBFA
# 4  5A1E6322-1057-42E2-BEBB-DED5A53D6884  BF23BB3C-1169-42C0-A1AD-41A1DC65CBFA
#
#                         criteriascoreid                       questionscoreid  \
# 0                                  None                                  None
# 1  B8E71257-155C-44F6-8D8E-144D0DE170DD  D54A2853-685E-4CEA-9A86-341F4E298DEE
# 2  B8E71257-155C-44F6-8D8E-144D0DE170DD  B53F283D-BF69-465E-83D4-B28627DFD38F
# 3  B8E71257-155C-44F6-8D8E-144D0DE170DD  80B48B9F-AB6C-413C-A96E-C393116F25A2
# 4  B8E71257-155C-44F6-8D8E-144D0DE170DD  194F91BA-6B32-45EC-9475-C3B68A9EE782
#
#   institutionid  assessmentyear   scoredate  mostrecentsequence  \
# 0         15333            2022  2023-03-17                   1
# 1         15333            2022  2023-03-17                   1
# 2         15333            2022  2023-03-17                   1
# 3         15333            2022  2023-03-17                   1
# 4         15333            2022  2023-03-17                   1
#
#                        csaindustrymapid csaindustryname  ... msacasedate  \
# 0  C0F2A1B7-C793-4320-BEB1-C54524337F22   INS Insurance  ...        None
# 1  C0F2A1B7-C793-4320-BEB1-C54524337F22   INS Insurance  ...        None
# 2  C0F2A1B7-C793-4320-BEB1-C54524337F22   INS Insurance  ...        None
# 3  C0F2A1B7-C793-4320-BEB1-C54524337F22   INS Insurance  ...        None
# 4  C0F2A1B7-C793-4320-BEB1-C54524337F22   INS Insurance  ...        None
#
#   msacasetitle msacasescore msacaseimpactlevelname msacaseimpactrating  \
# 0         None         None                   None                None
# 1         None         None                   None                None
# 2         None         None                   None                None
# 3         None         None                   None                None
# 4         None         None                   None                None
#
#   msacaseresponsename msacaseresponserating msaimpactid msaimpactdate  \
# 0                None                  None        None          None
# 1                None                  None        None          None
# 2                None                  None        None          None
# 3                None                  None        None          None
# 4                None                  None        None          None
#
#   criteriascoreimpact
# 0                None
# 1                None
# 2                None
# 3                None
# 4                None
#
# [5 rows x 41 columns]

# %%
sp_esg_wrds.shape
# Out:
# (5, 41)

# %%
# Extrating first 5 rows of sp_esg wrds_esg_facts
sp_esg_wrds_f = conn.get_table(library='sp_esg', table='wrds_esg_facts', obs=5)
sp_esg_wrds_f
# Out:
#   institutionid                               scoreid  \
# 0       4170432  DD019033-A598-437A-838F-774129EB2822
# 1       4170432  DD019033-A598-437A-838F-774129EB2822
# 2       4170432  DD019033-A598-437A-838F-774129EB2822
# 3       4170432  DD019033-A598-437A-838F-774129EB2822
# 4       4170432  DD019033-A598-437A-838F-774129EB2822
#
#                        dimensionscoreid                       criteriascoreid  \
# 0  E904D5E8-AAB8-4BFA-8905-31CA9A473F0B  9A115C6F-0597-439B-BBBC-DBD6524F8D31
# 1  E904D5E8-AAB8-4BFA-8905-31CA9A473F0B  9A115C6F-0597-439B-BBBC-DBD6524F8D31
# 2  E904D5E8-AAB8-4BFA-8905-31CA9A473F0B  9A115C6F-0597-439B-BBBC-DBD6524F8D31
# 3  E904D5E8-AAB8-4BFA-8905-31CA9A473F0B  9A115C6F-0597-439B-BBBC-DBD6524F8D31
# 4  E904D5E8-AAB8-4BFA-8905-31CA9A473F0B  9A115C6F-0597-439B-BBBC-DBD6524F8D31
#
#                         questionscoreid  factreplyyear      questionname  \
# 0  00000335-988C-412B-956D-0C7E54EA898F           2022  People Analytics
# 1  00000335-988C-412B-956D-0C7E54EA898F           2022  People Analytics
# 2  00000335-988C-412B-956D-0C7E54EA898F           2022  People Analytics
# 3  00000335-988C-412B-956D-0C7E54EA898F           2022  People Analytics
# 4  00000335-988C-412B-956D-0C7E54EA898F           2022  People Analytics
#
#                                             factname factdetail  \
# 0  TAR / People Analytics / Strategic Workforce P...       None
# 1  TAR / People Analytics / Organizational Networ...       None
# 2                 TAR / People Analytics / Selection       None
# 3  TAR / People Analytics / Measuring Employee Pe...       None
# 4              TAR / People Analytics / Flight Risks       None
#
#                                    factdetaildisplay  ...  factreplyraw  \
# 0  Use of People Analytics in strategic workforce...  ...           YES
# 1  Use of People Analytics for organizational net...  ...            NO
# 2             Company's Use of People Analytics (PA)  ...    Applicable
# 3  Use of People Analytics for measuring employee...  ...           YES
# 4  Use of People Analytics for flight risks analysis  ...           YES
#
#   factreplycomments factreplyrawcalculated  reportedunit factreplycurrency  \
# 0              None                      0          None               USD
# 1              None                      0          None               USD
# 2              None                      0          None               USD
# 3              None                      0          None               USD
# 4              None                      0          None               USD
#
#   factsourcename questionfactspublic  questionfactspartpublic  \
# 0            SAM                   0                        0
# 1            SAM                   0                        0
# 2            SAM                   0                        0
# 3            SAM                   0                        0
# 4            SAM                   0                        0
#
#    questionfactsshared  questionfactsflexible
# 0                    1                      0
# 1                    1                      0
# 2                    1                      0
# 3                    1                      0
# 4                    1                      0
#
# [5 rows x 21 columns]

# %%
sp_esg_wrds_f.shape
# Out:
# (5, 21)

# %%
# Exploring tr esg tables.
conn.list_tables(library='tresgsmp')
# Out:
# ['wrds_ref_esg']

# %%
# Exploring tr esg tables.
conn.list_tables(library='tresg')
# Out:
# ['esgasrepdata',
#  'esgcode',
#  'esgdesc',
#  'esgdniratings',
#  'esgenvdatapoint',
#  'esgenvindicator',
#  'esggovdatapoint',
#  'esggovindicator',
#  'esgitem',
#  'esgorgindcls',
#  'esgscores',
#  'esgsocdatapoint',
#  'esgsocindicator',
#  'esgsourcedata',
#  'esgsourcemap',
#  'esgstmtdet',
#  'wrds_ref_esg',
#  'wrds_ref_esg_item']

# %%
# Exploring tr esg tables.
conn.list_tables(library='tr_esg')
# Out:
# ['esgasrepdata',
#  'esgcode',
#  'esgdesc',
#  'esgdniratings',
#  'esgenvdatapoint',
#  'esgenvindicator',
#  'esggovdatapoint',
#  'esggovindicator',
#  'esgitem',
#  'esgorgindcls',
#  'esgscores',
#  'esgsocdatapoint',
#  'esgsocindicator',
#  'esgsourcedata',
#  'esgsourcemap',
#  'esgstmtdet',
#  'wrds_ref_esg',
#  'wrds_ref_esg_item']

# %%
# Extrating data for tr_esg ratings table
tr_esg_ratings = conn.get_table(library='tr_esg', table='esgdniratings')
unique_values = tr_esg_ratings['orgpermid'].unique()

# Counting the unique company ids with esg ratings
unique_count = len(unique_values)
unique_count
# Out:
# 12562

# %%
# Extrating data for tr_esg ratings table
tr_esg_scores = conn.get_table(library='tr_esg', table='esgscores')
unique_values = tr_esg_scores['orgpermid'].unique()

# Counting the unique company ids with esg scores
unique_count = len(unique_values)
unique_count
# Out:
# 14749

# %%
# Extrating first 5 rows of data for tr_esg ratings table
tr_esg_rep_data = conn.get_table(library='tr_esg', table='esgasrepdata', obs=5)
tr_esg_rep_data
# Out:
#     orgpermid  item    fy    valueid scalecode unitcode      value_
# 0  4295613014    34  2016  505189817      None     None  47300000.0
# 1  4295613014    34  2017  505188870      None     None  48000000.0
# 2  4295613014    34  2018  505108579      None     None  47700000.0
# 3  4295613014    45  2013  505262753      None     None         0.0
# 4  4295613014    45  2014  505223532      None     None         0.0

# %%
# Exploing comp tables
conn.list_tables(library='comp')
# Out:
# ['aco_amda',
#  'aco_imda',
#  'aco_indfnta',
#  'aco_indfntq',
#  'aco_indfntytd',
#  'aco_indsta',
#  'aco_indstq',
#  'aco_indstytd',
#  'aco_notesa',
#  'aco_notesq',
#  'aco_notessa',
#  'aco_notesytd',
#  'aco_pnfnda',
#  'aco_pnfndq',
#  'aco_pnfndytd',
#  'aco_pnfnta',
#  'aco_pnfntq',
#  'aco_pnfntytd',
#  'aco_transa',
#  'aco_transq',
#  'aco_transsa',
#  'aco_transytd',
#  'adsprate',
#  'asec_amda',
#  'asec_imda',
#  'asec_notesa',
#  'asec_notesq',
#  'asec_transa',
#  'asec_transq',
#  'bank_aacctchg',
#  'bank_adesind',
#  'bank_afnd1',
#  'bank_afnd2',
#  'bank_afnddc1',
#  'bank_afnddc2',
#  'bank_afntind',
#  'bank_funda',
#  'bank_funda_fncd',
#  'bank_fundq',
#  'bank_fundq_fncd',
#  'bank_iacctchg',
#  'bank_idesind',
#  'bank_ifndq',
#  'bank_ifndytd',
#  'bank_ifntq',
#  'bank_ifntytd',
#  'bank_names',
#  'bank_namesq',
#  'chars',
#  'co_aacctchg',
#  'co_aaudit',
#  'co_acthist',
#  'co_adesind',
#  'co_adjfact',
#  'co_afnd1',
#  'co_afnd2',
#  'co_afnddc1',
#  'co_afnddc2',
#  'co_afntind1',
#  'co_afntind2',
#  'co_ainvval',
#  'co_amkt',
#  'co_busdescl',
#  'co_cotype',
#  'co_filedate',
#  'co_fortune',
#  'co_hgic',
#  'co_iacctchg',
#  'co_iaudit',
#  'co_idesind',
#  'co_ifndq',
#  'co_ifndsa',
#  'co_ifndytd',
#  'co_ifntq',
#  'co_ifntsa',
#  'co_ifntytd',
#  'co_imkt',
#  'co_industry',
#  'co_ipcd',
#  'co_mthly',
#  'co_offtitl',
#  'company',
#  'currency',
#  'dd_group',
#  'dd_group_xref',
#  'dd_item',
#  'dd_package',
#  'ecind_desc',
#  'ecind_mth',
#  'exrt_dly',
#  'exrt_mth',
#  'filings',
#  'funda',
#  'funda_fncd',
#  'fundq',
#  'fundq_fncd',
#  'g_bmiindex',
#  'g_bmiindexdlynumvalue',
#  'g_bmiindexidentifier',
#  'g_bmiindexrel',
#  'g_bmiindextradingitem',
#  'g_chars',
#  'g_co_aaudit',
#  'g_co_adesind',
#  'g_co_afnd1',
#  'g_co_afnd2',
#  'g_co_afnddc1',
#  'g_co_afnddc2',
#  'g_co_afntind1',
#  'g_co_afntind2',
#  'g_co_ainvval',
#  'g_co_gsuppl',
#  'g_co_hgic',
#  'g_co_iaudit',
#  'g_co_idesind',
#  'g_co_ifndq',
#  'g_co_ifndsa',
#  'g_co_ifndytd',
#  'g_co_ifntq',
#  'g_co_ifntsa',
#  'g_co_ifntytd',
#  'g_co_industry',
#  'g_co_ipcd',
#  'g_co_offtitl',
#  'g_company',
#  'g_currency',
#  'g_ecind_desc',
#  'g_ecind_mth',
#  'g_exrt_dly',
#  'g_exrt_mth',
#  'g_funda',
#  'g_funda_fncd',
#  'g_fundq',
#  'g_fundq_fncd',
#  'g_idx_daily',
#  'g_idx_index',
#  'g_idx_mth',
#  'g_idxcst_his',
#  'g_names',
#  'g_names_ix',
#  'g_names_ix_cst',
#  'g_namesq',
#  'g_sec_adesind',
#  'g_sec_adjfact',
#  'g_sec_afnd',
#  'g_sec_afnddc',
#  'g_sec_afnt',
#  'g_sec_divid',
#  'g_sec_dprc',
#  'g_sec_dtrt',
#  'g_sec_gmdivfn',
#  'g_sec_gmth',
#  'g_sec_gmthdiv',
#  'g_sec_gmthprc',
#  'g_sec_history',
#  'g_sec_idesind',
#  'g_sec_ifnd',
#  'g_sec_ifnt',
#  'g_sec_split',
#  'g_secd',
#  'g_secm',
#  'g_secnamesd',
#  'g_security',
#  'g_sedolgvkey',
#  'g_tmptable_pkg5629_tbl3474',
#  'g_tmptable_pkg5629_tbl3476',
#  'g_tmptable_pkg5629_tbl3477',
#  'g_tmptable_pkg5629_tbl3478',
#  'g_tmptable_pkg5629_tbl3485',
#  'g_tmptable_pkg5638_tbl3474',
#  'g_tmptable_pkg5638_tbl3476',
#  'g_tmptable_pkg5638_tbl3477',
#  'g_tmptable_pkg5638_tbl3478',
#  'g_tmptable_pkg5638_tbl3485',
#  'g_tmptable_pkg5643_tbl3474',
#  'g_tmptable_pkg5643_tbl3476',
#  'g_tmptable_pkg5643_tbl3477',
#  'g_tmptable_pkg5643_tbl3478',
#  'g_tmptable_pkg5643_tbl3485',
#  'g_tmptable_pkg6153_tbl4023',
#  'gsecnamesm',
#  'idx_ann',
#  'idx_anndes',
#  'idx_daily',
#  'idx_index',
#  'idx_mth',
#  'idx_qrt',
#  'idx_qrtdes',
#  'idxcst_his',
#  'io_qaggregate',
#  'io_qbuysell',
#  'io_qchanges',
#  'io_qfloatadj',
#  'io_qholders',
#  'it_mbuysell',
#  'it_msummary',
#  'it_r_rltn',
#  'names',
#  'names_aco_indsta',
#  'names_aco_indstq',
#  'names_aco_pnfnda',
#  'names_aco_pnfndq',
#  'names_adsprate',
#  'names_ix',
#  'names_ix_cst',
#  'names_seg',
#  'namesd',
#  'namesm',
#  'namesq',
#  'r_accstd',
#  'r_acqmeth',
#  'r_auditors',
#  'r_auopic',
#  'r_balpres',
#  'r_cf_formt',
#  'r_co_status',
#  'r_coindpre',
#  'r_compstat',
#  'r_consol',
#  'r_country',
#  'r_cstclscd',
#  'r_datacode',
#  'r_datafmt',
#  'r_divtaxmarker',
#  'r_docsrce',
#  'r_ex_codes',
#  'r_exchgtier',
#  'r_exrt_typ',
#  'r_fndfntcd',
#  'r_footnts',
#  'r_foricd',
#  'r_giccd',
#  'r_hcalendr',
#  'r_idxclscd',
#  'r_inactvcd',
#  'r_incstats',
#  'r_indfmt',
#  'r_indsec',
#  'r_invval',
#  'r_issuetyp',
#  'r_majidxcl',
#  'r_mic_codes',
#  'r_naiccd',
#  'r_notetype',
#  'r_ntsubtype',
#  'r_offcrso',
#  'r_ogmethod',
#  'r_opinions',
#  'r_prc_stat',
#  'r_qsrcdoc',
#  'r_sec_stat',
#  'r_secannfn',
#  'r_sectors',
#  'r_siccd',
#  'r_spiicd',
#  'r_spmicd',
#  'r_statalrt',
#  'r_states',
#  'r_stko',
#  'r_titles',
#  'r_updates',
#  'sec_adesind',
#  'sec_adjfact',
#  'sec_afnd',
#  'sec_afnddc',
#  'sec_afnt',
#  'sec_divid',
#  'sec_dprc',
#  'sec_dtrt',
#  'sec_history',
#  'sec_idcurrent',
#  'sec_idesind',
#  'sec_idhist',
#  'sec_ifnd',
#  'sec_ifnt',
#  'sec_mdivfn',
#  'sec_mshare',
#  'sec_msptfn',
#  'sec_mth',
#  'sec_mthdiv',
#  'sec_mthprc',
#  'sec_mthspt',
#  'sec_mthtrt',
#  'sec_shortint',
#  'sec_spind',
#  'sec_split',
#  'secd',
#  'secm',
#  'security',
#  'sedolgvkey',
#  'seg_ann',
#  'seg_annfund',
#  'seg_customer',
#  'seg_geo',
#  'seg_naics',
#  'seg_product',
#  'seg_type',
#  'spidx_cst',
#  'spind',
#  'spind_dly',
#  'spind_mth',
#  'tmptable_pkg6153_tbl4023',
#  'wrds_g_exrate',
#  'wrds_idx_cst_current',
#  'wrds_ratios',
#  'wrds_seg_customer',
#  'wrds_seg_geo',
#  'wrds_seg_product',
#  'wrds_segmerged',
#  'xfl_column',
#  'xfl_table']

# %%
# Querying some data from WRDS server
company = conn.get_table(library='comp', table='company', obs=10)
company
# Out:
#                        conm   gvkey                                      add1  \
# 0     A & E PLASTIK PAK INC  001000                                      None
# 1   A & M FOOD SERVICES INC  001001                   1924 South Utica Avenue
# 2                  AAI CORP  001002                         124 Industry Lane
# 3     A.A. IMPORTING CO INC  001003                          7700 Hall Street
# 4                  AAR CORP  001004  One AAR Place, 1100 North Wood Dale Road
# 5     A.B.A. INDUSTRIES INC  001005                 10260 US Highway 19 North
# 6              ABC INDS INC  001006                         301 Kings Highway
# 7      ABKCO INDUSTRIES INC  001007                   1700 Broadway, Suite 41
# 8  ABM COMPUTER SYSTEMS INC  001008                                 3 Whatney
# 9        ABS INDUSTRIES INC  001009              Interstate Square, Suite 300
#
#    add2  add3  add4      addzip  \
# 0  None  None  None        None
# 1  None  None  None       94104
# 2  None  None  None  21030-0126
# 3  None  None  None       63125
# 4  None  None  None       60191
# 5  None  None  None       33782
# 6  None  None  None       46590
# 7  None  None  None       10019
# 8  None  None  None       92714
# 9  None  None  None       44904
#
#                                              busdesc         cik  \
# 0  A & E Plastik Pak Inc. is a commodity chemical...        None
# 1                                               None  0000723576
# 2  Textron Systems Corporation designs, develops,...  0001306124
# 3  A.A. Importing Company, Inc. designs, manufact...  0000730052
# 4  AAR Corp. provides products and services to co...  0000001750
# 5  A.B.A. Industries Inc. was acquired by McSwain...        None
# 6  ABC Industries, Inc. manufactures and supplies...        None
# 7  ABKCO Music & Records, Inc. is a prominent ind...  0000001882
# 8  ABM Computer Systems Inc. was acquired by Fran...        None
# 9  ABS Industries, Inc., through Colfor and Colma...  0000313368
#
#             city  ...   sic spcindcd spcseccd spcsrc state stko  \
# 0           None  ...  3089      325      978   None  None    0
# 1          Tulsa  ...  5812      420      978   None    OK    0
# 2    Hunt Valley  ...  3825      230      940   None    MD    0
# 3      St. Louis  ...  5712      449      976   None    MO    3
# 4      Wood Dale  ...  5080      110      925      B    IL    0
# 5  Pinellas Park  ...  3724      110      925   None    FL    0
# 6    Winona Lake  ...  2711      415      976   None    IN    3
# 7       New York  ...  3652      220      925   None    NY    3
# 8         Irvine  ...  3577      188      940   None    CA    0
# 9     Willoughby  ...  3460      355      925   None    OH    3
#
#                    weburl       dldte     ipodate curr_sp500_flag
# 0                    None  1978-06-30        None             0.0
# 1                    None  1986-07-31        None             0.0
# 2  www.textronsystems.com  1977-03-31        None             0.0
# 3     www.aaimporting.com  1992-04-30        None             0.0
# 4         www.aarcorp.com        None  1972-04-24             0.0
# 5                    None  1983-01-31        None             0.0
# 6  www.abc-industries.net  1983-06-30        None             0.0
# 7           www.abkco.com  1986-12-31        None             0.0
# 8                    None  1987-10-31        None             0.0
# 9                    None  1996-12-31        None             0.0
#
# [10 rows x 40 columns]

# %%
company.shape
# Out:
# (10, 40)

# %% [markdown]
# # Step 1: Research & Prototype
#
# Goal: Begin with a small, manageable dataset and build a proof-of-concept (PoC) to validate the feasibility of the ESG-based recommendation approach. This step helps ensure that our planned APIs, data models, and algorithms are compatible, reliable, and useful before moving on to a larger-scale MVP.

# %% [markdown]
# 1. Identify Data Sources
# - Open Sustainability Index API:
#
#     Focus: Start by exploring the `emissions` and `targets` endpoints. Confirm that we can retrieve:
#
#     Scope 1, 2, and 3 emissions data for a small set of companies.
#     `sbt_status` and net-zero commitments to gauge ESG commitments.
#
#     Action: Pick 5-10 companies (diverse in industry and size) and fetch their ESG metrics from the API.
#
#     Deliverable: A JSON or CSV file containing ESG data for these target companies.
#
#     https://www.opensustainabilityindex.org/api

# %%
base_url = "https://api.opensustainabilityindex.org/v1"
osi_api_key = "demo"

def get_industries():
    # This endpoint returns a list of industries.
    url = f"{base_url}/industries"
    params = {
        "api-key": osi_api_key,
        "limit": 300,
        "offset": 0,
        "order": "desc"
    }

    response = requests.get(url, params=params)
    response.raise_for_status()
    data = response.json().get("data", [])
    return data

def get_companies_by_industry(industry_name, limit=300, offset=0):
    # This function retrieves companies for a given industry name.
    url = f"{base_url}/companies"
    params = {
        "api-key": osi_api_key,
        "limit": limit,
        "offset": offset,
        "order": "desc",
        "industry": industry_name
    }

    response = requests.get(url, params=params)
    response.raise_for_status()
    data = response.json().get("data", [])
    error = response.json().get("error", None)

    if error:
        # If the API returns an error field, handle it here
        print(f"Error retrieving companies for industry '{industry_name}': {error}")
        return []

    # "data" should represent companies now if the industry name is correct
    return data

def main():
    # Step 1: Get all industries
    industries = get_industries()

    # Step 2: Iterate over each industry and fetch its companies
    for industry in industries:
        industry_name = industry.get("name")
        company_count = industry.get("company_count", 0)

        print(f"\n=== Industry: {industry_name}")
        print(f"Company count: {company_count}")

        if company_count > 0:
            # Retrieve companies for this industry's name (not slug)
            companies = get_companies_by_industry(industry_name, limit=min(company_count, 300))
            if companies:
                for c in companies:
                    company_name = c.get("company_name", c.get("name", "Unknown"))
                    print(f"- {company_name}")
            else:
                print("No company data returned for this industry.")
        else:
            print("No companies listed for this industry.")

if __name__ == "__main__":
    main()
# Out:
# === Industry: Aerospace and Defense
# Company count: 27
# - Saab AB
# - CTT Systems AB
# - Airbus
#
# === Industry: Air Freight Transportation and Logistics
# Company count: 79
# - PostNord AB
# - DSV A / S
#
# === Industry: Air Transportation - Airlines
# Company count: 29
# No company data returned for this industry.
#
# === Industry: Air Transportation - Airport Services
# Company count: 14
# No company data returned for this industry.
#
# === Industry: Automobiles and Components
# Company count: 293
# - Volvo Car Group
# - Volkswagen AG
# - Toyota Motor Corporation
# - Tesla Inc.
# - Mercedes-Benz AG
# - Ford Motor Company
# - Bulten AB
# - BMW Group
# - Autoliv Inc
#
# === Industry: Banks, Diverse Financials, Insurance
# Company count: 273
# - Zurich Insurance Group Ltd
# - UnitedHealth Group
# - Tokio Marine Holdings, Inc.
# - Swedbank AB
# - Svenska Handelsbanken publ.
# - Storskogen Group
# - Shinhan Financial Group
# - SBAB
# - Sampo plc
# - MetLife, Inc.
# - KB Financial Group
# - Intesa Sanpaolo
# - ING Group
# - If P&C Insurance Holding Ltd. (publ)
# - EQT AB
# - Danske Bank
# - Credit Suisse Group
# - Banco do Brasil S.A.
# - AXA Group
# - Aviva PLC
# - Avanza Bank Holding AB
# - Altor Equity Partners AB
# - AIA Group Limited
# - 3i Group plc
#
# === Industry: Building Products
# Company count: 169
# - Rockwool Group
# - Lindab International AB
# - Inwido AB
# - Diab International AB
#
# === Industry: Chemicals
# Company count: 234
# - Perstorp Holding AB
# - Novozymes A/S
# - Linde plc
# - HEXPOL AB
# - 3M
#
# === Industry: Construction Materials
# Company count: 107
# - Holcim Ltd.
#
# === Industry: Construction and Engineering
# Company count: 429
# - Vestum
# - Skanska AB
# - Rejlers AB
# - Bravida Holding AB
# - ACCIONA S.A.
#
# === Industry: Construction and materials
# Company count: 2
# No company data returned for this industry.
#
# === Industry: Consumer Durables, Household and Personal Products
# Company count: 312
# - Unilever plc
# - Thule Group AB
# - Sony Group Corporation
# - Procter & Gamble Company
# - Nobia AB
# - Mips AB
# - Lintex AB
# - Karo Healthcare AB
# - Husqvarna AB
# - Hultafors Group AB
# - GN Store Nord A/S
# - Essity AB
# - Electrolux Group
# - Clas Ohlson AB (publ)
# - BHG Group
# - AB Pictura
#
# === Industry: Containers and Packaging
# Company count: 237
# - Ecolean
#
# === Industry: Education Services
# Company count: 14
# No company data returned for this industry.
#
# === Industry: Electric Utilities and Independent Power Producers and Energy Traders (including fossil, alternative and nuclear energy)
# Company count: 151
# - Ørsted
# - Vattenfall AB
# - RWE AG
# - OX2 AB
# - National Grid (Group) PLC
# - Iberdrola SA
# - Fortum Corporation
# - Enel SpA
# - EDF Group
#
# === Industry: Electrical Equipment and Machinery
# Company count: 574
# - Vestas Wind Systems
# - Valmet
# - Systemair AB
# - Siemens AG
# - Schneider Electric
# - SCANIA CV
# - Sandvik Group
# - NKT Cables Group A/S
# - Nederman Holding AB
# - Konecranes Oyj
# - KONE Corporation
# - Indutrade AB
# - Honeywell International Inc.
# - Fagerhult Group
# - Epiroc AB
# - engcon AB
# - Deere & Company
# - Cargotec
# - Bufab AB
# - Atlas Copco AB
# - Alfa Laval AB
# - Addtech AB
# - ABB
# - AB SKF
#
# === Industry: Food Production - Agricultural Production
# Company count: 105
# No company data returned for this industry.
#
# === Industry: Food Production - Animal Source Food Production
# Company count: 54
# No company data returned for this industry.
#
# === Industry: Food and Beverage Processing
# Company count: 509
# - The Coca-Cola Company
# - Spendrups Bryggeri AB
# - Scandi Standard AB
# - PepsiCo, Inc.
# - Nestlé
# - Mondelez International Inc
# - Midsona AB
# - Lantmännen Cerealia
# - Greenfood AB
# - Foodmark AB
# - Di Luca & Di Luca AB
# - Danone
# - Cloetta AB
# - Carlsberg Group
# - Bama Fresh Cuts AB
# - Arla Foods
# - AB Anders Löfberg
# - AAK
#
# === Industry: Food and Staples Retailing
# Company count: 96
# - Walmart Inc.
# - The Kroger Co.
# - Seven & i Holdings Co., Ltd.
# - Kesko Corporation
# - ICA Gruppen
# - CVS Health
# - Convini Sverige AB
# - Café Bar Sverige AB
# - Axfood AB
# - Apotea
#
# === Industry: Forest and Paper Products - Forestry, Timber, Pulp and Paper, Rubber
# Company count: 126
# - UPM-Kymmene Corporation
# - Stora Enso
# - Huhtamäki Oyj
# - Holmen AB
# - Duni Group
# - Billerud AB
#
# === Industry: Ground Transportation - Highways and Railtracks
# Company count: 28
# - Knorr-Bremse AG
#
# === Industry: Ground Transportation - Railroads Transportation
# Company count: 53
# - Union Pacific Corporation
# - Alstom
#
# === Industry: Ground Transportation - Trucking Transportation
# Company count: 129
# - REMONDIS Sweden AB.
# - Nobina AB
# - Movator AB
# - Ahréns Åkeri AB
#
# === Industry: Healthcare Equipment and Supplies
# Company count: 73
# - Vitrolife Group
# - Mölnlycke Health Care AB
# - Medtronic PLC
# - Getinge AB
# - Elekta AB
# - Coloplast A/S
# - Asker Healthcare Group AB
# - Arjo AB
# - Ambu
#
# === Industry: Healthcare Providers and Services, and Healthcare Technology
# Company count: 64
# - Humana Inc.
# - Demant A/S
# - Anthem, Inc.
#
# === Industry: Homebuilding
# Company count: 39
# - Resona Utveckling AB
# - Bonava AB
#
# === Industry: Hotels, Restaurants and Leisure, and Tourism Services
# Company count: 146
# - SkiStar AB
# - NH Hotel Group
# - McDonald's Corporation
# - Marriott International, Inc.
# - Accor S.A.
#
# === Industry: Media
# Company count: 112
# - WPP Plc
# - Viaplay Group AB
# - The Walt Disney Company
# - The Economist Group
# - Storytel AB (publ)
# - Sky Group
# - News Corp
# - Netflix
# - Meta Platforms, Inc.
# - Bonnier Books
# - Alma Media
#
# === Industry: Mining - Iron, Aluminum, Other Metals
# Company count: 103
# - SSAB
# - Höganäs AB
# - Gränges AB
# - Boliden AB (publ)
#
# === Industry: Mining - Other (Rare Minerals, Precious Metals and Gems)
# Company count: 15
# No company data returned for this industry.
#
# === Industry: Mining-iron, aluminium, other metals
# Company count: 2
# No company data returned for this industry.
#
# === Industry: Pharmaceuticals, Biotechnology and Life Sciences
# Company count: 240
# - Thermo Fisher Scientific Inc.
# - Takeda Pharmaceutical Company
# - SANOFI
# - Red Glead Discovery AB
# - Recipharm
# - Pfizer Inc.
# - Orion Corporation
# - Novo Nordisk A/S
# - Novartis
# - McKesson Corporation
# - Johnson & Johnson
# - GSK
# - Gilead Sciences, Inc.
# - Danaher Corporation
# - Bristol Myers Squibb
# - BioGaia AB
# - Bayer AG
# - AstraZeneca
# - Amgen Inc.
# - AbbVie
#
# === Industry: Professional Services
# Company count: 847
# - Securitas AB
# - Nexer Group AB
# - MiljöMatematik Malmö AB
# - Mannheimer Swartling
# - KPMG International Limited
# - Knightec
# - AFRY (ÅF Pöyry)
# - Accenture PLC
#
# === Industry: Real Estate
# Company count: 322
# - Wihlborgs Fastigheter
# - Wallenstam AB
# - Vasakronan AB
# - Specialfastigheter Sverige AB
# - Samhällsbyggnadsbolaget i Norden AB
# - Rikshem AB
# - Riksbyggen
# - Platzer Fastigheter Holding AB (publ)
# - Pandox AB
# - NP3 Fastigheter AB
# - Magnolia Bostad AB
# - LSTH Svenska Handelsfastigheter AB
# - K2A Knaust & Andersson
# - John Mattson Fastighetsföretagen AB
# - Hufvudstaden AB
# - Hemsö Fastighets AB
# - Heimstaden Bostad AB
# - Heba Fastighets AB
# - Genova Property Group AB
# - Fastpartner AB
# - Fastighets AB Balder
# - Fabege AB
# - Einar Mattsson AB
# - Diös Fastigheter
# - Cibus Nordic Real Estate AB (publ)
# - Catena AB
# - Castellum AB
# - Atrium Ljungberg AB
# - Arwidsro Fastighets AB
# - AMF FASTIGHETER AB
# - Akademiska hus
# - AB Svenska bostäder
# - AB Sagax
#
# === Industry: Retailing
# Company count: 250
# - The Home Depot
# - Target Corporation
# - RugVista AB
# - Open Air Group
# - Office Depot Svenska AB
# - MEKO AB
# - HL Display AB
# - Gina Tricot
# - Dormy Golf & Fashion AB
# - Boozt
# - Apoteket AB
# - Amazon
#
# === Industry: Semiconductors and Semiconductors Equipment
# Company count: 71
# - Qualcomm Incorporated
# - Broadcom Inc.
#
# === Industry: Software and Services
# Company count: 557
# - Visa Inc.
# - TietoEVRY
# - Tencent Holdings Limited
# - Stillfront Group AB (publ)
# - SeenThis AB
# - PayPal
# - Nordlo Group AB
# - Microsoft Corporation
# - Mastercard
# - Loopia Group AB
# - Knowit AB (publ)
# - Iver Management AB
# - IFS
# - Hexagon AB
# - Hemnet AB
# - Genexis Group
# - Embracer Group AB
# - Betsson AB
# - Alphabet Inc.
# - Advania Sverige AB
#
# === Industry: Solid Waste Management Utilities
# Company count: 71
# - Stena Recycling Group
#
# === Industry: Specialized Consumer Services
# Company count: 57
# No company data returned for this industry.
#
# === Industry: Specialized Financial Services, Consumer Finance, Insurance Brokerage Firms
# Company count: 41
# - American Express Company
#
# === Industry: Technology Hardware and Equipment
# Company count: 264
# - Nolato AB
# - Nokia Group
# - Mycronic
# - HP Inc
# - Hon Hai Precision Inc. Co., Ltd.
# - HMS Networks AB
# - Hitachi, Ltd.
# - Hexatronic Group AB
# - Ericsson Group
# - Dell Technologies
# - Cisco Systems, Inc.
# - Assa Abloy AB
# - Apple, Inc.
#
# === Industry: Telecommunication Services
# Company count: 172
# - Vodafone Group Plc
# - Telia Company
# - Telenor Group
# - TELEFÓNICA
# - Tele2 AB
# - SoftBank Corp.
# - ORANGE
# - Netel Holding AB (publ)
# - Millicom International Cellular S.A.
# - KDDI Corporation
# - Eltel AB
# - Elisa Corporation
# - Comcast
# - America Movil, S.A.B. de C.V.
#
# === Industry: Textile Manufacturing, Spinning, Weaving & Apparel
# Company count: 2
# No company data returned for this industry.
#
# === Industry: Textiles, Apparel, Footwear and Luxury Goods
# Company count: 505
# - Pandora A/S
# - NIKE, Inc.
# - NA-KD
# - LVMH
# - Kappahl AB
# - Happy Socks
# - H&M Group
# - Eton Group AB
#
# === Industry: Tires
# Company count: 15
# No company data returned for this industry.
#
# === Industry: Tobacco
# Company count: 10
# - Philip Morris International
# - Altria Group, Inc.
#
# === Industry: Trading Companies and Distributors, and Commercial Services and Supplies
# Company count: 342
# - Oleter Group AB
# - ISS A/S
# - Godsinlösen Nordic AB
# - Foxway Group AB
# - Elanders AB
# - EG Electronics AB
# - Coor Service Management Holding AB
# - Beijer Ref AB
#
# === Industry: Water Transportation - Ports and Services
# Company count: 11
# No company data returned for this industry.
#
# === Industry: Water Transportation - Water Transportation
# Company count: 18
# - A.P. Moller - Maersk A/S
#
# === Industry: Water Utilities
# Company count: 24
# No company data returned for this industry.

# %%
# Temporary workaround until we get the esg api key
# Downloading the static file directly from the Open Sustainability API website
esg_path = '/content/drive/Shareddrives/mosa_fall2024_hackathon/Data/'

with open(esg_path+"esg.json", "r") as f:
  esg_data = json.load(f)

esg_data
# Out:
# {'data': [{'company_name': 'Ørsted',
#    'slug': 'orsted',
#    'company_url': None,
#    'industry': 'Electric Utilities and Independent Power Producers and Energy Traders (including fossil, alternative and nuclear energy)',
#    'organization_type': 'Company',
#    'tags': 'omx120',
#    'commitment_type': 'BA1.5 Option 1',
#    'status': 'Target set',
#    'commitment_deadline': '2021-09-30',
#    'total_reported_emission_scope_1_2_3': 7217000,
#    'revenue': 11508,
#    'hq_country': 'Denmark',
#    'year': 2023,
#    'currency': 'DKK',
#    'emission_intensity': 627,
#    'targets': [{'target_type': 'Intensity',
#      'target_scope': '1+2+3',
#      'target_year': 2040,
#      'target': 'Long-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '1+2',
#      'target_year': 2040,
#      'target': 'Long-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2040,
#      'target': 'Long-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '1+2',
#      'target_year': 2025,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2032,
#      'target': 'Near-term'},
#     {'target_type': 'Net-zero',
#      'target_scope': '1+2+3',
#      'target_year': 2040,
#      'target': 'Net-zero'}]},
#   {'company_name': 'Zurich Insurance Group Ltd',
#    'slug': 'zurich-insurance',
#    'company_url': None,
#    'industry': 'Banks, Diverse Financials, Insurance',
#    'organization_type': 'Financial Institution',
#    'tags': None,
#    'commitment_type': 'BA1.5 Option 1',
#    'status': 'Extended',
#    'commitment_deadline': '2022-09-30',
#    'total_reported_emission_scope_1_2_3': 55119,
#    'revenue': 41890,
#    'hq_country': 'Switzerland',
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 1,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'Xano Industri',
#    'slug': 'xano-industri',
#    'company_url': None,
#    'industry': None,
#    'organization_type': None,
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 8182,
#    'revenue': 337,
#    'hq_country': None,
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 24,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'Wärtsilä Oyj',
#    'slug': 'wartsila',
#    'company_url': None,
#    'industry': None,
#    'organization_type': None,
#    'tags': 'omx120',
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 2073903,
#    'revenue': 6511,
#    'hq_country': None,
#    'year': 2023,
#    'currency': 'EUR',
#    'emission_intensity': 319,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'WPP Plc',
#    'slug': 'wpp',
#    'company_url': None,
#    'industry': 'Media',
#    'organization_type': 'Company',
#    'tags': None,
#    'commitment_type': 'BA1.5 Option 1',
#    'status': 'Removed',
#    'commitment_deadline': '2024-01-31',
#    'total_reported_emission_scope_1_2_3': 5161438,
#    'revenue': 15404,
#    'hq_country': 'United Kingdom',
#    'year': 2020,
#    'currency': 'GBP',
#    'emission_intensity': 335,
#    'targets': [{'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2025,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2025,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2025,
#      'target': 'Near-term'}]},
#   {'company_name': 'World Courier Sweden AB',
#    'slug': 'world-courier-sweden',
#    'company_url': None,
#    'industry': None,
#    'organization_type': None,
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 147662236,
#    'revenue': 230000,
#    'hq_country': None,
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 642,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'Wihlborgs Fastigheter',
#    'slug': 'wihlborgs-fastigheter',
#    'company_url': None,
#    'industry': 'Real Estate',
#    'organization_type': 'SME',
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 18501,
#    'revenue': 320,
#    'hq_country': 'Sweden',
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 58,
#    'targets': [{'target_type': 'Net-zero',
#      'target_scope': '1+2+3',
#      'target_year': 2045,
#      'target': 'Net-zero'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2+3',
#      'target_year': 2045,
#      'target': 'Long-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'}]},
#   {'company_name': 'Westpac Banking Group',
#    'slug': 'westpac-banking',
#    'company_url': None,
#    'industry': None,
#    'organization_type': None,
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 3343,
#    'revenue': 18710,
#    'hq_country': None,
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 0,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'Wells Fargo',
#    'slug': 'wells-fargo',
#    'company_url': None,
#    'industry': None,
#    'organization_type': None,
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 2718080,
#    'revenue': 108930,
#    'hq_country': None,
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 25,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'Walmart Inc.',
#    'slug': 'walmart',
#    'company_url': '28.49',
#    'industry': 'Food and Staples Retailing',
#    'organization_type': 'Company',
#    'tags': None,
#    'commitment_type': 'BA1.5 Option 2',
#    'status': 'Removed',
#    'commitment_deadline': '2024-01-31',
#    'total_reported_emission_scope_1_2_3': 13990000,
#    'revenue': 611290,
#    'hq_country': 'United States of America',
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 23,
#    'targets': [{'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2025,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'}]},
#   {'company_name': 'Wallenstam AB',
#    'slug': 'wallenstam',
#    'company_url': None,
#    'industry': 'Real Estate',
#    'organization_type': 'SME',
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 15892,
#    'revenue': 257,
#    'hq_country': 'Sweden',
#    'year': 2023,
#    'currency': 'SEK',
#    'emission_intensity': 62,
#    'targets': [{'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'}]},
#   {'company_name': 'Volvo Car Group',
#    'slug': 'volvo-car',
#    'company_url': 'volvogroup.com',
#    'industry': 'Automobiles and Components',
#    'organization_type': 'Company',
#    'tags': 'omx120',
#    'commitment_type': 'BA1.5 Option 2',
#    'status': 'Extended',
#    'commitment_deadline': '2024-01-31',
#    'total_reported_emission_scope_1_2_3': 266294000,
#    'revenue': 52126,
#    'hq_country': 'Sweden',
#    'year': 2023,
#    'currency': 'SEK',
#    'emission_intensity': 5109,
#    'targets': [{'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'}]},
#   {'company_name': 'Volkswagen AG',
#    'slug': 'volkswagen',
#    'company_url': None,
#    'industry': 'Automobiles and Components',
#    'organization_type': 'Company',
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 419940000,
#    'revenue': 302044,
#    'hq_country': 'Germany',
#    'year': 2023,
#    'currency': 'EUR',
#    'emission_intensity': 1390,
#    'targets': [{'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '3',
#      'target_year': 2025,
#      'target': 'Near-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'}]},
#   {'company_name': 'Volati',
#    'slug': 'volati',
#    'company_url': None,
#    'industry': None,
#    'organization_type': None,
#    'tags': None,
#    'commitment_type': 'Net-zero',
#    'status': 'Active',
#    'commitment_deadline': '2026-09-30',
#    'total_reported_emission_scope_1_2_3': 5160,
#    'revenue': 748,
#    'hq_country': None,
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 7,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'Vodafone Group Plc',
#    'slug': 'vodafone',
#    'company_url': None,
#    'industry': 'Telecommunication Services',
#    'organization_type': 'Company',
#    'tags': None,
#    'commitment_type': 'BA1.5 Option 1',
#    'status': 'Target set',
#    'commitment_deadline': '2022-07-31',
#    'total_reported_emission_scope_1_2_3': 2670000,
#    'revenue': 49740,
#    'hq_country': 'United Kingdom',
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 54,
#    'targets': [{'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2040,
#      'target': 'Long-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2040,
#      'target': 'Long-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2040,
#      'target': 'Long-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2040,
#      'target': 'Long-term'},
#     {'target_type': 'Net-zero',
#      'target_scope': '1+2+3',
#      'target_year': 2040,
#      'target': 'Net-zero'},
#     {'target_type': 'Net-zero',
#      'target_scope': '1+2+3',
#      'target_year': 2040,
#      'target': 'Net-zero'},
#     {'target_type': 'Renewable electricity',
#      'target_scope': '2',
#      'target_year': 2025,
#      'target': 'Near-term'},
#     {'target_type': 'Renewable electricity',
#      'target_scope': '2',
#      'target_year': 2025,
#      'target': 'Near-term'},
#     {'target_type': 'Renewable electricity',
#      'target_scope': '2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Renewable electricity',
#      'target_scope': '2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'}]},
#   {'company_name': 'VNV Global',
#    'slug': 'vnv-global',
#    'company_url': None,
#    'industry': None,
#    'organization_type': None,
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 8,
#    'revenue': None,
#    'hq_country': None,
#    'year': 2021,
#    'currency': 'USD',
#    'emission_intensity': None,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'Vitrolife Group',
#    'slug': 'vitrolife',
#    'company_url': None,
#    'industry': 'Healthcare Equipment and Supplies',
#    'organization_type': 'Company',
#    'tags': None,
#    'commitment_type': 'Standard',
#    'status': 'Active',
#    'commitment_deadline': '2025-10-31',
#    'total_reported_emission_scope_1_2_3': 2817,
#    'revenue': 186,
#    'hq_country': 'Sweden',
#    'year': 2021,
#    'currency': 'USD',
#    'emission_intensity': 15,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'Vitol',
#    'slug': 'vitol',
#    'company_url': None,
#    'industry': None,
#    'organization_type': None,
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 30800000,
#    'revenue': None,
#    'hq_country': None,
#    'year': 2023,
#    'currency': 'USD',
#    'emission_intensity': None,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'Visa Inc.',
#    'slug': 'visa',
#    'company_url': None,
#    'industry': 'Software and Services',
#    'organization_type': 'Company',
#    'tags': None,
#    'commitment_type': 'BA1.5 Option 1',
#    'status': 'Active',
#    'commitment_deadline': '2024-01-31',
#    'total_reported_emission_scope_1_2_3': 471200,
#    'revenue': 30980,
#    'hq_country': 'United States of America',
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 15,
#    'targets': [{'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'}]},
#   {'company_name': 'Vimian Group',
#    'slug': 'vimian',
#    'company_url': None,
#    'industry': None,
#    'organization_type': None,
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 1793,
#    'revenue': 289,
#    'hq_country': None,
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 6,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'Viaplay Group AB',
#    'slug': 'viaplay',
#    'company_url': None,
#    'industry': 'Media',
#    'organization_type': 'Company',
#    'tags': None,
#    'commitment_type': 'BA1.5 Option 1',
#    'status': 'Removed',
#    'commitment_deadline': '2024-01-31',
#    'total_reported_emission_scope_1_2_3': 92700,
#    'revenue': 1490,
#    'hq_country': 'Sweden',
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 62,
#    'targets': [{'target_type': 'Engagement',
#      'target_scope': '3',
#      'target_year': 2026,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Engagement',
#      'target_scope': '3',
#      'target_year': 2026,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Engagement',
#      'target_scope': '3',
#      'target_year': 2026,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'}]},
#   {'company_name': 'Vestum',
#    'slug': 'vestum',
#    'company_url': None,
#    'industry': 'Construction and Engineering',
#    'organization_type': 'Company',
#    'tags': None,
#    'commitment_type': 'Net-zero',
#    'status': 'Active',
#    'commitment_deadline': '2025-03-31',
#    'total_reported_emission_scope_1_2_3': 44900,
#    'revenue': 665,
#    'hq_country': 'Sweden',
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 68,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None},
#     {'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'Vestas Wind Systems',
#    'slug': 'vestas-wind-systems',
#    'company_url': 'vestas.com',
#    'industry': 'Electrical Equipment and Machinery',
#    'organization_type': 'Company',
#    'tags': 'omx120',
#    'commitment_type': 'BA1.5 Option 2',
#    'status': 'Removed',
#    'commitment_deadline': '2024-01-31',
#    'total_reported_emission_scope_1_2_3': 7769000,
#    'revenue': 16649,
#    'hq_country': 'Denmark',
#    'year': 2023,
#    'currency': 'EUR',
#    'emission_intensity': 467,
#    'targets': [{'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'}]},
#   {'company_name': 'Verizon Communications',
#    'slug': 'verizon-communications',
#    'company_url': None,
#    'industry': None,
#    'organization_type': None,
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 19131492,
#    'revenue': 134350,
#    'hq_country': None,
#    'year': 2021,
#    'currency': 'USD',
#    'emission_intensity': 142,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'Veidekke Entreprenad',
#    'slug': 'veidekke-entreprenad',
#    'company_url': None,
#    'industry': None,
#    'organization_type': None,
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 125729,
#    'revenue': 4036,
#    'hq_country': None,
#    'year': 2022,
#    'currency': 'NOK',
#    'emission_intensity': 31,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'Vattenfall AB',
#    'slug': 'vattenfall',
#    'company_url': 'vattenfall.com',
#    'industry': 'Electric Utilities and Independent Power Producers and Energy Traders (including fossil, alternative and nuclear energy)',
#    'organization_type': 'Company',
#    'tags': None,
#    'commitment_type': 'BA1.5 Option 1',
#    'status': 'Target set',
#    'commitment_deadline': '2024-01-31',
#    'total_reported_emission_scope_1_2_3': 16200000,
#    'revenue': 23773,
#    'hq_country': 'Sweden',
#    'year': 2022,
#    'currency': 'SEK',
#    'emission_intensity': 681,
#    'targets': [{'target_type': 'Intensity',
#      'target_scope': '1+2',
#      'target_year': 2040,
#      'target': 'Long-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2040,
#      'target': 'Long-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2040,
#      'target': 'Long-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '1+3',
#      'target_year': 2040,
#      'target': 'Long-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '1+3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Net-zero',
#      'target_scope': '1+2+3',
#      'target_year': 2040,
#      'target': 'Net-zero'},
#     {'target_type': 'Intensity',
#      'target_scope': '1+2',
#      'target_year': 2040,
#      'target': 'Long-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2040,
#      'target': 'Long-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2040,
#      'target': 'Long-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '1+3',
#      'target_year': 2040,
#      'target': 'Long-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '1+3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Net-zero',
#      'target_scope': '1+2+3',
#      'target_year': 2040,
#      'target': 'Net-zero'},
#     {'target_type': 'Intensity',
#      'target_scope': '1+2',
#      'target_year': 2040,
#      'target': 'Long-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2040,
#      'target': 'Long-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2040,
#      'target': 'Long-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '1+3',
#      'target_year': 2040,
#      'target': 'Long-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '1+3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Net-zero',
#      'target_scope': '1+2+3',
#      'target_year': 2040,
#      'target': 'Net-zero'},
#     {'target_type': 'Intensity',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'}]},
#   {'company_name': 'Vasakronan AB',
#    'slug': 'vasakronan',
#    'company_url': None,
#    'industry': 'Real Estate',
#    'organization_type': 'Company',
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 37216,
#    'revenue': 864,
#    'hq_country': 'Sweden',
#    'year': 2023,
#    'currency': 'SEK',
#    'emission_intensity': 43,
#    'targets': [{'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Renewable electricity',
#      'target_scope': '2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'}]},
#   {'company_name': 'Valmet',
#    'slug': 'valmet',
#    'company_url': 'valmet.com',
#    'industry': 'Electrical Equipment and Machinery',
#    'organization_type': 'Company',
#    'tags': 'omx120',
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 64743500,
#    'revenue': 5988,
#    'hq_country': 'Finland',
#    'year': 2023,
#    'currency': 'EUR',
#    'emission_intensity': 10812,
#    'targets': [{'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'}]},
#   {'company_name': 'Valero Energy',
#    'slug': 'valero-energy',
#    'company_url': None,
#    'industry': None,
#    'organization_type': None,
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 286000,
#    'revenue': 114000,
#    'hq_country': None,
#    'year': 2021,
#    'currency': 'USD',
#    'emission_intensity': 3,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'UPM-Kymmene Corporation',
#    'slug': 'upm-kymmene',
#    'company_url': 'upm.com',
#    'industry': 'Forest and Paper Products - Forestry, Timber, Pulp and Paper, Rubber',
#    'organization_type': 'Company',
#    'tags': 'omx120',
#    'commitment_type': 'BA1.5 Option 1',
#    'status': 'Active',
#    'commitment_deadline': '2022-01-31',
#    'total_reported_emission_scope_1_2_3': 11330000,
#    'revenue': 11322,
#    'hq_country': 'Finland',
#    'year': 2023,
#    'currency': 'EUR',
#    'emission_intensity': 1001,
#    'targets': [{'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'}]},
#   {'company_name': 'UnitedHealth Group',
#    'slug': 'unitedhealth',
#    'company_url': 'uhg.com',
#    'industry': 'Banks, Diverse Financials, Insurance',
#    'organization_type': 'Financial Institution',
#    'tags': None,
#    'commitment_type': 'Net-zero',
#    'status': 'Active',
#    'commitment_deadline': '2024-06-30',
#    'total_reported_emission_scope_1_2_3': 14294830,
#    'revenue': 335940,
#    'hq_country': 'United States of America',
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 43,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None},
#     {'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'United Parcel Service',
#    'slug': 'united-parcel-service',
#    'company_url': None,
#    'industry': None,
#    'organization_type': None,
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 33159000,
#    'revenue': 98550,
#    'hq_country': None,
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 336,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'Uniper SE',
#    'slug': 'uniper-se',
#    'company_url': None,
#    'industry': None,
#    'organization_type': None,
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 97651529,
#    'revenue': 116807,
#    'hq_country': None,
#    'year': 2023,
#    'currency': 'EUR',
#    'emission_intensity': 836,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'Union Pacific Corporation',
#    'slug': 'union-pacific',
#    'company_url': None,
#    'industry': 'Ground Transportation - Railroads Transportation',
#    'organization_type': 'Company',
#    'tags': None,
#    'commitment_type': 'Net-zero',
#    'status': 'Active',
#    'commitment_deadline': '2024-11-30',
#    'total_reported_emission_scope_1_2_3': 15316383,
#    'revenue': 25070,
#    'hq_country': 'United States of America',
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 611,
#    'targets': [{'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'}]},
#   {'company_name': 'Unilever plc',
#    'slug': 'unilever',
#    'company_url': None,
#    'industry': 'Consumer Durables, Household and Personal Products',
#    'organization_type': 'Company',
#    'tags': None,
#    'commitment_type': 'BA1.5 Option 2',
#    'status': 'Removed',
#    'commitment_deadline': '2024-01-31',
#    'total_reported_emission_scope_1_2_3': 35390000,
#    'revenue': 63110,
#    'hq_country': 'United Kingdom',
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 561,
#    'targets': [{'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'}]},
#   {'company_name': 'UniCredit',
#    'slug': 'unicredit',
#    'company_url': None,
#    'industry': None,
#    'organization_type': None,
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 85244,
#    'revenue': 21030,
#    'hq_country': None,
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 4,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'UBS',
#    'slug': 'ubs',
#    'company_url': None,
#    'industry': None,
#    'organization_type': None,
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 131920,
#    'revenue': 39890,
#    'hq_country': None,
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 3,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'TUIfly Nordic AB',
#    'slug': 'tuifly-nordic',
#    'company_url': None,
#    'industry': None,
#    'organization_type': None,
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 6656,
#    'revenue': 22369,
#    'hq_country': None,
#    'year': 2023,
#    'currency': 'EUR',
#    'emission_intensity': 0,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'Tryg',
#    'slug': 'tryg',
#    'company_url': None,
#    'industry': None,
#    'organization_type': None,
#    'tags': 'omx120',
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 4180,
#    'revenue': 40195,
#    'hq_country': None,
#    'year': 2023,
#    'currency': 'EUR',
#    'emission_intensity': 0,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'Truist Financial',
#    'slug': 'truist-financial',
#    'company_url': None,
#    'industry': None,
#    'organization_type': None,
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 254743,
#    'revenue': 28000,
#    'hq_country': None,
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 9,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'Travelers',
#    'slug': 'travelers',
#    'company_url': None,
#    'industry': None,
#    'organization_type': None,
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 48244,
#    'revenue': 37790,
#    'hq_country': None,
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 1,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'Toyota Motor Corporation',
#    'slug': 'toyota-motor',
#    'company_url': None,
#    'industry': 'Automobiles and Components',
#    'organization_type': 'Company',
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 575730000,
#    'revenue': 270490,
#    'hq_country': 'Japan',
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 2128,
#    'targets': [{'target_type': 'Intensity',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2035,
#      'target': 'Near-term'}]},
#   {'company_name': 'TotalEnergies SE',
#    'slug': 'totalenergies-se',
#    'company_url': None,
#    'industry': None,
#    'organization_type': None,
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 389000000,
#    'revenue': 237128,
#    'hq_country': None,
#    'year': 2023,
#    'currency': 'USD',
#    'emission_intensity': 1640,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'Tokio Marine Holdings, Inc.',
#    'slug': 'tokio-marine-holdings',
#    'company_url': None,
#    'industry': 'Banks, Diverse Financials, Insurance',
#    'organization_type': None,
#    'tags': None,
#    'commitment_type': 'Standard',
#    'status': 'Removed',
#    'commitment_deadline': '2021-02-28',
#    'total_reported_emission_scope_1_2_3': 80201,
#    'revenue': 48670,
#    'hq_country': 'Japan',
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 2,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'Tobii Dynavox',
#    'slug': 'tobii-dynavox',
#    'company_url': None,
#    'industry': None,
#    'organization_type': None,
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 2049,
#    'revenue': 117,
#    'hq_country': None,
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 18,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'TietoEVRY',
#    'slug': 'tietoevry',
#    'company_url': 'tietoevry.com',
#    'industry': 'Software and Services',
#    'organization_type': 'Company',
#    'tags': 'omx120',
#    'commitment_type': 'BA1.5 Option 1',
#    'status': 'Target set',
#    'commitment_deadline': '2023-01-31',
#    'total_reported_emission_scope_1_2_3': 207018,
#    'revenue': 3086,
#    'hq_country': 'Finland',
#    'year': 2023,
#    'currency': 'EUR',
#    'emission_intensity': 67,
#    'targets': [{'target_type': 'Engagement',
#      'target_scope': '3',
#      'target_year': 2026,
#      'target': 'Near-term'},
#     {'target_type': 'Renewable electricity',
#      'target_scope': '2',
#      'target_year': 2026,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2026,
#      'target': 'Near-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'}]},
#   {'company_name': 'Thule Group AB',
#    'slug': 'thule',
#    'company_url': 'thulegroup.com',
#    'industry': 'Consumer Durables, Household and Personal Products',
#    'organization_type': 'Company',
#    'tags': 'omx120',
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 173319,
#    'revenue': 861,
#    'hq_country': 'Sweden',
#    'year': 2023,
#    'currency': 'SEK',
#    'emission_intensity': 201,
#    'targets': [{'target_type': 'Absolute',
#      'target_scope': '1',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2050,
#      'target': 'Long-term'},
#     {'target_type': 'Renewable electricity',
#      'target_scope': '2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Net-zero',
#      'target_scope': '1+2+3',
#      'target_year': 2050,
#      'target': 'Net-zero'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2050,
#      'target': 'Long-term'}]},
#   {'company_name': 'Thermo Fisher Scientific Inc.',
#    'slug': 'thermo-fisher-scientific',
#    'company_url': None,
#    'industry': 'Pharmaceuticals, Biotechnology and Life Sciences',
#    'organization_type': 'Company',
#    'tags': None,
#    'commitment_type': 'BA1.5 Option 2',
#    'status': 'Target set',
#    'commitment_deadline': '2024-01-31',
#    'total_reported_emission_scope_1_2_3': 13337413,
#    'revenue': 43810,
#    'hq_country': 'United States of America',
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 304,
#    'targets': [{'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Engagement',
#      'target_scope': '3',
#      'target_year': 2027,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2050,
#      'target': 'Long-term'},
#     {'target_type': 'Net-zero',
#      'target_scope': '1+2+3',
#      'target_year': 2050,
#      'target': 'Net-zero'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2050,
#      'target': 'Long-term'}]},
#   {'company_name': 'The Walt Disney Company',
#    'slug': 'walt-disney',
#    'company_url': None,
#    'industry': 'Media',
#    'organization_type': 'Company',
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 1603776,
#    'revenue': 84070,
#    'hq_country': 'United States of America',
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 19,
#    'targets': [{'target_type': 'Engagement',
#      'target_scope': '3',
#      'target_year': 2027,
#      'target': 'Near-term'},
#     {'target_type': 'Engagement',
#      'target_scope': '3',
#      'target_year': 2027,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'}]},
#   {'company_name': 'The Kroger Co.',
#    'slug': 'kroger',
#    'company_url': None,
#    'industry': 'Food and Staples Retailing',
#    'organization_type': 'Company',
#    'tags': None,
#    'commitment_type': 'Standard',
#    'status': 'Active',
#    'commitment_deadline': '2024-06-30',
#    'total_reported_emission_scope_1_2_3': 6957969,
#    'revenue': 132500,
#    'hq_country': 'United States of America',
#    'year': 2020,
#    'currency': 'USD',
#    'emission_intensity': 53,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'The Home Depot',
#    'slug': 'home-depot',
#    'company_url': 'homedepot.com',
#    'industry': 'Retailing',
#    'organization_type': 'Company',
#    'tags': None,
#    'commitment_type': 'Standard',
#    'status': 'Active',
#    'commitment_deadline': '2023-05-31',
#    'total_reported_emission_scope_1_2_3': 5253500,
#    'revenue': 157400,
#    'hq_country': 'United States of America',
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 33,
#    'targets': [{'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-Term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-Term'}]},
#   {'company_name': 'The Economist Group',
#    'slug': 'economist',
#    'company_url': None,
#    'industry': 'Media',
#    'organization_type': 'Company',
#    'tags': None,
#    'commitment_type': 'BA1.5 Option 1',
#    'status': 'Target set',
#    'commitment_deadline': '2023-10-31',
#    'total_reported_emission_scope_1_2_3': 35195,
#    'revenue': None,
#    'hq_country': 'United Kingdom',
#    'year': 2019,
#    'currency': 'USD',
#    'emission_intensity': None,
#    'targets': [{'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Renewable electricity',
#      'target_scope': '2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'}]},
#   {'company_name': 'The Coca-Cola Company',
#    'slug': 'coca-cola',
#    'company_url': None,
#    'industry': 'Food and Beverage Processing',
#    'organization_type': 'Company',
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 5413463,
#    'revenue': 43310,
#    'hq_country': 'United States of America',
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 125,
#    'targets': [{'target_type': 'Absolute',
#      'target_scope': '1+2+3',
#      'target_year': 2030,
#      'target': 'Near-term'}]},
#   {'company_name': 'Tesla Inc.',
#    'slug': 'tesla',
#    'company_url': None,
#    'industry': 'Automobiles and Components',
#    'organization_type': 'Company',
#    'tags': None,
#    'commitment_type': 'BA1.5 Option 1',
#    'status': 'Extended',
#    'commitment_deadline': '2023-10-31',
#    'total_reported_emission_scope_1_2_3': 28720000,
#    'revenue': 86030,
#    'hq_country': 'United States of America',
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 334,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'Tencent Holdings Limited',
#    'slug': 'tencent-holdings',
#    'company_url': None,
#    'industry': 'Software and Services',
#    'organization_type': 'Company',
#    'tags': None,
#    'commitment_type': 'Net-zero',
#    'status': 'Active',
#    'commitment_deadline': '2024-02-29',
#    'total_reported_emission_scope_1_2_3': 5739724,
#    'revenue': 82410,
#    'hq_country': 'China',
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 70,
#    'targets': [{'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Renewable electricity',
#      'target_scope': '2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Renewable electricity',
#      'target_scope': '2',
#      'target_year': 2030,
#      'target': 'Near-term'}]},
#   {'company_name': 'Telia Company',
#    'slug': 'telia',
#    'company_url': 'teliacompany.com',
#    'industry': 'Telecommunication Services',
#    'organization_type': 'Company',
#    'tags': 'omx120',
#    'commitment_type': 'BA1.5 Option 1',
#    'status': 'Target set',
#    'commitment_deadline': '2024-01-31',
#    'total_reported_emission_scope_1_2_3': 11907,
#    'revenue': 8372,
#    'hq_country': 'Sweden',
#    'year': 2023,
#    'currency': 'SEK',
#    'emission_intensity': 1,
#    'targets': [{'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2025,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2040,
#      'target': 'Long-term'},
#     {'target_type': 'Engagement',
#      'target_scope': '3',
#      'target_year': 2025,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2040,
#      'target': 'Long-term'},
#     {'target_type': 'Net-zero',
#      'target_scope': '1+2+3',
#      'target_year': 2040,
#      'target': 'Net-zero'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2025,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2040,
#      'target': 'Long-term'},
#     {'target_type': 'Engagement',
#      'target_scope': '3',
#      'target_year': 2025,
#      'target': 'Near-term'},
#     {'target_type': 'Engagement',
#      'target_scope': '3',
#      'target_year': 2025,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2040,
#      'target': 'Long-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2025,
#      'target': 'Near-term'},
#     {'target_type': 'Net-zero',
#      'target_scope': '1+2+3',
#      'target_year': 2040,
#      'target': 'Net-zero'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2040,
#      'target': 'Long-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2040,
#      'target': 'Long-term'},
#     {'target_type': 'Net-zero',
#      'target_scope': '1+2+3',
#      'target_year': 2040,
#      'target': 'Net-zero'}]},
#   {'company_name': 'Telenor Group',
#    'slug': 'telenor',
#    'company_url': None,
#    'industry': 'Telecommunication Services',
#    'organization_type': 'Company',
#    'tags': None,
#    'commitment_type': 'Net-zero',
#    'status': 'Active',
#    'commitment_deadline': '2025-05-31',
#    'total_reported_emission_scope_1_2_3': 2908186,
#    'revenue': 7627,
#    'hq_country': 'Norway',
#    'year': 2023,
#    'currency': 'NOK',
#    'emission_intensity': 381,
#    'targets': [{'target_type': 'Engagement',
#      'target_scope': '3',
#      'target_year': 2025,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2+3',
#      'target_year': 2045,
#      'target': 'Long-term'},
#     {'target_type': 'Net-zero',
#      'target_scope': '1+2+3',
#      'target_year': 2045,
#      'target': 'Net-zero'},
#     {'target_type': 'Engagement',
#      'target_scope': '3',
#      'target_year': 2025,
#      'target': 'Near-term'},
#     {'target_type': 'Engagement',
#      'target_scope': '3',
#      'target_year': 2025,
#      'target': 'Near-term'},
#     {'target_type': 'Engagement',
#      'target_scope': '3',
#      'target_year': 2025,
#      'target': 'Near-term'}]},
#   {'company_name': 'TELEFÓNICA',
#    'slug': 'telefonica',
#    'company_url': 'telefonica.com',
#    'industry': 'Telecommunication Services',
#    'organization_type': 'Company',
#    'tags': None,
#    'commitment_type': 'BA1.5 Option 1',
#    'status': 'Target set',
#    'commitment_deadline': '2024-01-31',
#    'total_reported_emission_scope_1_2_3': 2821685,
#    'revenue': 49100,
#    'hq_country': 'Spain',
#    'year': 2020,
#    'currency': 'USD',
#    'emission_intensity': 57,
#    'targets': [{'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2040,
#      'target': 'Long-term'},
#     {'target_type': 'Net-zero',
#      'target_scope': '1+2+3',
# ...
#   {'company_name': 'Specialfastigheter Sverige AB',
#    'slug': 'specialfastigheter-sverige',
#    'company_url': 'specialfastigheter.se',
#    'industry': 'Real Estate',
#    'organization_type': 'SME',
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 32450,
#    'revenue': 289,
#    'hq_country': 'Sweden',
#    'year': 2023,
#    'currency': 'SEK',
#    'emission_intensity': 112,
#    'targets': [{'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'}]},
#   {'company_name': 'Southern Company',
#    'slug': 'southern',
#    'company_url': None,
#    'industry': None,
#    'organization_type': None,
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 123500000,
#    'revenue': 29279,
#    'hq_country': None,
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 4218,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'Sony Group Corporation',
#    'slug': 'sony',
#    'company_url': None,
#    'industry': 'Consumer Durables, Household and Personal Products',
#    'organization_type': 'Company',
#    'tags': None,
#    'commitment_type': 'BA1.5 Option 1',
#    'status': 'Target set',
#    'commitment_deadline': '2022-08-31',
#    'total_reported_emission_scope_1_2_3': 21420000,
#    'revenue': 85150,
#    'hq_country': 'Japan',
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 252,
#    'targets': [{'target_type': 'Absolute',
#      'target_scope': '1+2+3',
#      'target_year': 2040,
#      'target': 'Long-term'},
#     {'target_type': 'Engagement',
#      'target_scope': '3',
#      'target_year': 2025,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2035,
#      'target': 'Near-term'},
#     {'target_type': 'Net-zero',
#      'target_scope': '1+2+3',
#      'target_year': 2040,
#      'target': 'Net-zero'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2035,
#      'target': 'Near-term'}]},
#   {'company_name': 'SoftBank Corp.',
#    'slug': 'softbank',
#    'company_url': 'softbank.com',
#    'industry': 'Telecommunication Services',
#    'organization_type': 'Company',
#    'tags': None,
#    'commitment_type': 'Net-zero',
#    'status': 'Active',
#    'commitment_deadline': '2025-06-30',
#    'total_reported_emission_scope_1_2_3': 3742416,
#    'revenue': 70300,
#    'hq_country': 'Japan',
#    'year': 2020,
#    'currency': 'USD',
#    'emission_intensity': 53,
#    'targets': [{'target_type': 'Net-zero',
#      'target_scope': '1+2+3',
#      'target_year': 2050,
#      'target': 'Net-zero'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2050,
#      'target': 'Long-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2031,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2031,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2050,
#      'target': 'Long-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'}]},
#   {'company_name': 'Sky Group',
#    'slug': 'sky',
#    'company_url': None,
#    'industry': 'Media',
#    'organization_type': 'Company',
#    'tags': None,
#    'commitment_type': 'BA1.5 Option 1',
#    'status': 'Removed',
#    'commitment_deadline': '2024-01-31',
#    'total_reported_emission_scope_1_2_3': 2341414,
#    'revenue': 18567,
#    'hq_country': 'United Kingdom',
#    'year': 2020,
#    'currency': 'GBP',
#    'emission_intensity': 126,
#    'targets': [{'target_type': 'Absolute',
#      'target_scope': '1+2+3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2+3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2+3',
#      'target_year': 2030,
#      'target': 'Near-term'}]},
#   {'company_name': 'SkiStar AB',
#    'slug': 'skistar',
#    'company_url': 'skistar.com',
#    'industry': 'Hotels, Restaurants and Leisure, and Tourism Services',
#    'organization_type': 'Company',
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 150467,
#    'revenue': 425,
#    'hq_country': 'Sweden',
#    'year': 2022,
#    'currency': 'SEK',
#    'emission_intensity': 354,
#    'targets': [{'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Engagement',
#      'target_scope': '3',
#      'target_year': 2027,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Renewable electricity',
#      'target_scope': '2',
#      'target_year': 2030,
#      'target': 'Near-term'}]},
#   {'company_name': 'Skanska AB',
#    'slug': 'skanska',
#    'company_url': None,
#    'industry': 'Construction and Engineering',
#    'organization_type': 'Company',
#    'tags': 'omx120',
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 1176000,
#    'revenue': 15764,
#    'hq_country': 'Sweden',
#    'year': 2023,
#    'currency': 'SEK',
#    'emission_intensity': 75,
#    'targets': [{'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2045,
#      'target': 'Long-term pre-CNZS'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2045,
#      'target': 'Long-term pre-CNZS'}]},
#   {'company_name': 'SK Hynix',
#    'slug': 'sk-hynix',
#    'company_url': None,
#    'industry': None,
#    'organization_type': None,
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 5035786,
#    'revenue': 27000,
#    'hq_country': None,
#    'year': 2020,
#    'currency': 'USD',
#    'emission_intensity': 187,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'Sinopec',
#    'slug': 'sinopec',
#    'company_url': None,
#    'industry': None,
#    'organization_type': None,
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 161790000,
#    'revenue': 453560,
#    'hq_country': None,
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 357,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'Siemens AG',
#    'slug': 'siemens',
#    'company_url': None,
#    'industry': 'Electrical Equipment and Machinery',
#    'organization_type': 'Company',
#    'tags': None,
#    'commitment_type': 'BA1.5 Option 2',
#    'status': 'Active',
#    'commitment_deadline': '2024-01-31',
#    'total_reported_emission_scope_1_2_3': 458188000,
#    'revenue': 75874,
#    'hq_country': 'Germany',
#    'year': 2022,
#    'currency': 'EUR',
#    'emission_intensity': 6039,
#    'targets': [{'target_type': 'Net-zero',
#      'target_scope': '1+2+3',
#      'target_year': 2050,
#      'target': 'Net-zero'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2050,
#      'target': 'Long-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '3',
#      'target_year': 2050,
#      'target': 'Long-term'}]},
#   {'company_name': 'Shinhan Financial Group',
#    'slug': 'shinhan-financial',
#    'company_url': 'shinhangroup.com',
#    'industry': 'Banks, Diverse Financials, Insurance',
#    'organization_type': 'Financial Institution',
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 90877,
#    'revenue': 22900,
#    'hq_country': 'Korea, Republic of',
#    'year': 2020,
#    'currency': 'USD',
#    'emission_intensity': 4,
#    'targets': [{'target_type': 'Engagement',
#      'target_scope': '3',
#      'target_year': 2025,
#      'target': 'Near-term'},
#     {'target_type': 'Engagement',
#      'target_scope': '3',
#      'target_year': 2025,
#      'target': 'Near-term'},
#     {'target_type': 'Engagement',
#      'target_scope': '3',
#      'target_year': 2025,
#      'target': 'Near-term'},
#     {'target_type': 'Engagement',
#      'target_scope': '3',
#      'target_year': 2025,
#      'target': 'Near-term'},
#     {'target_type': 'Engagement',
#      'target_scope': '3',
#      'target_year': 2025,
#      'target': 'Near-term'},
#     {'target_type': 'Engagement',
#      'target_scope': '3',
#      'target_year': 2025,
#      'target': 'Near-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Intensity',
#      'target_scope': '3',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Engagement',
#      'target_scope': '3',
#      'target_year': 2025,
#      'target': 'Near-term'},
#     {'target_type': 'Engagement',
#      'target_scope': '3',
#      'target_year': 2025,
#      'target': 'Near-term'},
#     {'target_type': 'Engagement',
#      'target_scope': '3',
#      'target_year': 2025,
#      'target': 'Near-term'},
#     {'target_type': 'Engagement',
#      'target_scope': '3',
#      'target_year': 2025,
#      'target': 'Near-term'},
#     {'target_type': 'Engagement',
#      'target_scope': '3',
#      'target_year': 2025,
#      'target': 'Near-term'},
#     {'target_type': 'Engagement',
#      'target_scope': '3',
#      'target_year': 2025,
#      'target': 'Near-term'}]},
#   {'company_name': 'Shell',
#    'slug': 'shell',
#    'company_url': None,
#    'industry': None,
#    'organization_type': None,
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 57000000,
#    'revenue': 323183,
#    'hq_country': None,
#    'year': 2023,
#    'currency': 'USD',
#    'emission_intensity': 176,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'Seven & i Holdings Co., Ltd.',
#    'slug': 'seven-and-i-holdings',
#    'company_url': None,
#    'industry': 'Food and Staples Retailing',
#    'organization_type': None,
#    'tags': None,
#    'commitment_type': 'Standard',
#    'status': 'Removed',
#    'commitment_deadline': '2023-03-31',
#    'total_reported_emission_scope_1_2_3': 12618799,
#    'revenue': 88030,
#    'hq_country': 'Japan',
#    'year': 2022,
#    'currency': 'USD',
#    'emission_intensity': 143,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'Serneke Group AB (publ)',
#    'slug': 'serneke',
#    'company_url': None,
#    'industry': None,
#    'organization_type': None,
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 92190,
#    'revenue': 913,
#    'hq_country': None,
#    'year': 2022,
#    'currency': 'SEK',
#    'emission_intensity': 101,
#    'targets': [{'target_type': None,
#      'target_scope': None,
#      'target_year': None,
#      'target': None}]},
#   {'company_name': 'SeenThis AB',
#    'slug': 'seenthis',
#    'company_url': 'seenthis.co',
#    'industry': 'Software and Services',
#    'organization_type': 'SME',
#    'tags': None,
#    'commitment_type': None,
#    'status': None,
#    'commitment_deadline': None,
#    'total_reported_emission_scope_1_2_3': 5907,
#    'revenue': 11,
#    'hq_country': 'Sweden',
#    'year': 2022,
#    'currency': 'SEK',
#    'emission_intensity': 537,
#    'targets': [{'target_type': 'Absolute',
#      'target_scope': '1+2',
#      'target_year': 2030,
#      'target': 'Near-term'},
#     {'target_type': 'Net-zero',
#      'target_scope': '1+2+3',
#      'target_year': 2040,
#      'target': 'Net-zero'},
#     {'target_type': 'Absolute',
#      'target_scope': '1+2+3',
#      'target_year': 2040,
#      'target': 'Long-term'}]},
#   {'company_name': 'Securitas AB',
#    'slug': 'securitas',
#    'company_url': 'securitas.com',
#    'industry': 'Professional Services',
#    'organization_type': 'Company',
#    'tags': 'omx120',
#    'commitment_type': 'Standard',
#    'status': 'Target set',
#    'commitment_deadline': '2024-06-30',
#    'total_reported_emission_scope_1_2_3': 1916720,
#    'revenue': 14829,
#    'hq_country': 'Sweden',
#    'year': 2023,
#    'currency': 'SEK',
#    'emission_intensity': 129,
#    'targets': [{'target_type': 'Absolute',
#      'target_scope': '1+2+3',
#      'target_year': 2030,
#      'target': 'Near-term'}]}],
#  'error': None}

# %%
# Convert esg_data to esg_df, a pandas dataframe
# Create a dataframe for main company-level data (excluding targets)
companies_df = pd.json_normalize(esg_data['data']).drop(columns=['targets'])
companies_df
# Out:
#                     company_name                  slug    company_url  \
# 0                         Ørsted                orsted           None
# 1     Zurich Insurance Group Ltd      zurich-insurance           None
# 2                  Xano Industri         xano-industri           None
# 3                   Wärtsilä Oyj              wartsila           None
# 4                        WPP Plc                   wpp           None
# ..                           ...                   ...            ...
# 94                         Shell                 shell           None
# 95  Seven & i Holdings Co., Ltd.  seven-and-i-holdings           None
# 96       Serneke Group AB (publ)               serneke           None
# 97                   SeenThis AB              seenthis    seenthis.co
# 98                  Securitas AB             securitas  securitas.com
#
#                                              industry      organization_type  \
# 0   Electric Utilities and Independent Power Produ...                Company
# 1                Banks, Diverse Financials, Insurance  Financial Institution
# 2                                                None                   None
# 3                                                None                   None
# 4                                               Media                Company
# ..                                                ...                    ...
# 94                                               None                   None
# 95                         Food and Staples Retailing                   None
# 96                                               None                   None
# 97                              Software and Services                    SME
# 98                              Professional Services                Company
#
#       tags commitment_type      status commitment_deadline  \
# 0   omx120  BA1.5 Option 1  Target set          2021-09-30
# 1     None  BA1.5 Option 1    Extended          2022-09-30
# 2     None            None        None                None
# 3   omx120            None        None                None
# 4     None  BA1.5 Option 1     Removed          2024-01-31
# ..     ...             ...         ...                 ...
# 94    None            None        None                None
# 95    None        Standard     Removed          2023-03-31
# 96    None            None        None                None
# 97    None            None        None                None
# 98  omx120        Standard  Target set          2024-06-30
#
#     total_reported_emission_scope_1_2_3   revenue      hq_country  year  \
# 0                               7217000   11508.0         Denmark  2023
# 1                                 55119   41890.0     Switzerland  2022
# 2                                  8182     337.0            None  2022
# 3                               2073903    6511.0            None  2023
# 4                               5161438   15404.0  United Kingdom  2020
# ..                                  ...       ...             ...   ...
# 94                             57000000  323183.0            None  2023
# 95                             12618799   88030.0           Japan  2022
# 96                                92190     913.0            None  2022
# 97                                 5907      11.0          Sweden  2022
# 98                              1916720   14829.0          Sweden  2023
#
#    currency  emission_intensity
# 0       DKK               627.0
# 1       USD                 1.0
# 2       USD                24.0
# 3       EUR               319.0
# 4       GBP               335.0
# ..      ...                 ...
# 94      USD               176.0
# 95      USD               143.0
# 96      SEK               101.0
# 97      SEK               537.0
# 98      SEK               129.0
#
# [99 rows x 15 columns]

# %%
# Create a separate dataframe for targets
targets_df = pd.json_normalize(esg_data['data'], record_path = 'targets',
                               meta=[
                                 'company_name',
                                 'slug',
                                 'year',
                                 'hq_country'
                               ],
                               errors='ignore'
)
targets_df
# Out:
#     target_type target_scope  target_year     target             company_name  \
# 0     Intensity        1+2+3       2040.0  Long-term                   Ørsted
# 1     Intensity          1+2       2040.0  Long-term                   Ørsted
# 2      Absolute            3       2040.0  Long-term                   Ørsted
# 3     Intensity          1+2       2025.0  Near-term                   Ørsted
# 4      Absolute            3       2032.0  Near-term                   Ørsted
# ..          ...          ...          ...        ...                      ...
# 374        None         None          NaN       None  Serneke Group AB (publ)
# 375    Absolute          1+2       2030.0  Near-term              SeenThis AB
# 376    Net-zero        1+2+3       2040.0   Net-zero              SeenThis AB
# 377    Absolute        1+2+3       2040.0  Long-term              SeenThis AB
# 378    Absolute        1+2+3       2030.0  Near-term             Securitas AB
#
#           slug  year hq_country
# 0       orsted  2023    Denmark
# 1       orsted  2023    Denmark
# 2       orsted  2023    Denmark
# 3       orsted  2023    Denmark
# 4       orsted  2023    Denmark
# ..         ...   ...        ...
# 374    serneke  2022       None
# 375   seenthis  2022     Sweden
# 376   seenthis  2022     Sweden
# 377   seenthis  2022     Sweden
# 378  securitas  2023     Sweden
#
# [379 rows x 8 columns]

# %% [markdown]
# ## Explaining the ESG dataframe:
#
# Splitting into Two DataFrames: One for companies, one for targets.
#
# Since `target` is a list of target objects per comapny, we can separate it into its own dataframe using `pd.json_normalize()` and specifying `meta` fields from the parent level so that we can later join the targets back to the main data.
#
# By normalizing the data into two distinct tables - one for company-level attributes and one for targets - we maintain a reltationl structure. Each target row is linked back to the parent company via an identifier (e.g., `comapny_name` or `slug`).
#
# Our goal is to:
# - Filter targets independently.
# - Easily join the target back to the company data on shared keys.
# - Aggregate, pivot, or perform complex transformation on targets without repeatedly parsing nested objects.
#
# ## What is `target` in the ESG dataframe?
#
# In the esg data, the target refers to a company's climate or sustainability objectives - often emissions reduction goals, renewable energy commitments, or nest-zero pledges, typically tied to a centain date or criterion.
#
# - Target Type: Whether it’s an absolute emissions reduction (lowering overall greenhouse gas output) or an intensity reduction (lowering emissions per unit of revenue or production).
#
# - Target Scope: Which emissions scopes or categories are covered. For example:
#
#     Scope 1: Direct emissions from company-owned sources.
#
#     Scope 2: Indirect emissions from purchased electricity, steam, heating, and cooling.
#
#     Scope 3: All other indirect emissions that occur in a company’s value chain.
#
# - Target Year: The deadline by which the company intends to achieve this goal.
#
# - Target Aim: Whether it’s a near-term goal (e.g., by 2025 or 2030), a long-term goal (e.g., by 2040), or a net-zero target.

# %% [markdown]
# - Financial APIs (e.g., Polygon.io, AlphaVantage, yahoo finance):
#
#     Focus: Ensure we can pull historical stock price data or basic financial performance indicators for the same set of companies we gathered ESG data on.
#
#     Action: Use a free tier (if available) or sample data endpoints to fetch:
#
#     Daily closing prices over the last 1-3 months.
#
#     Basic financial ratios (if accessible) like P/E ratios or market cap.
#
#     Deliverable: A small CSV containing financial time series data aligned with the chosen companies.

# %%
# Define the tickers and time range
tickers = ["MSFT", "UL", "ORSTED.CO"]
end_date = datetime.today().date()
start_date = end_date - timedelta(days=20) # roughly 3 months of data

# Fetch data
data = yf.download(tickers, start=start_date, end=end_date)

# Returned df will have a multi-index with levels for ticker and OHLC info
# Focusing on daily closing prices and flatten the df
closing_prices = data['Close'].reset_index()
closing_prices.columns = ['Date'] + tickers
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
# Fetch basic financial ratios/info
info_records = []
for t in tickers:
    stock = yf.Ticker(t)
    info = stock.info
    # Extract some key metrics if available:
    record = {
        "Ticker": t,
        "ShortName": info.get("shortName", ""),
        "MarketCap": info.get("marketCap", None),
        "PE_Ratio": info.get("trailingPE", None),
        "ForwardPE": info.get("forwardPE", None),
        "DividendYield": info.get("dividendYield", None),
        "Sector": info.get("sector", ""),
        "Industry": info.get("industry", "")
    }
    info_records.append(record)

financial_df = pd.DataFrame(info_records)

# %%
closing_prices
# Out:
#          Date        MSFT          UL  ORSTED.CO
# 0  2024-11-29  423.459991  391.799988  59.840000
# 1  2024-12-02  430.980011  381.399994  59.910000
# 2  2024-12-03  431.200012  374.700012  59.380001
# 3  2024-12-04  437.420013  365.899994  59.369999
# 4  2024-12-05  442.619995  363.000000  59.549999
# 5  2024-12-06  443.570007  363.200012  59.040001
# 6  2024-12-09  446.019989  363.500000  58.840000
# 7  2024-12-10  443.329987  360.600006  58.709999
# 8  2024-12-11  448.989990  353.000000  58.779999
# 9  2024-12-12  449.559998  354.299988  58.709999
# 10 2024-12-13  447.269989  348.200012  58.869999
# 11 2024-12-16  451.589996  340.299988  59.320000
# 12 2024-12-17  454.459991  339.200012  59.299999
# 13 2024-12-18  437.390015  338.600006  57.830002

# %%
financial_df
# Out:
#       Ticker              ShortName      MarketCap   PE_Ratio  ForwardPE  \
# 0       MSFT  Microsoft Corporation  3249265704960  36.058582  29.085247
# 1         UL           Unilever PLC   145309155328  20.851450  18.524181
# 2  ORSTED.CO             ORSTED A/S   139558387712  27.698082  14.328260
#
#    DividendYield              Sector                       Industry
# 0         0.0076          Technology      Software - Infrastructure
# 1         0.0329  Consumer Defensive  Household & Personal Products
# 2            NaN           Utilities          Utilities - Renewable

# %%
# Saving the results
closing_prices.to_json("esg_stocks_closing_prices.json", index=False)
financial_df.to_json("esg_stocks_financial_info.json", index=False)

# %% [markdown]
# - Sentiment Analysis (Optional for Prototype):
#
#     Focus: This can be deferred since the first prototype might focus on ESG and basic financial data. But if we’d like a preview:
#
#     Pull a few news headlines from a free market API or scrape recent ESG-related headlines.
#
#     Use a simple NLP model (e.g., a publicly available sentiment library) to tag sentiment.
#
#     Action (Optional): Annotate 5-10 news items for sentiment.
#
#     Deliverable: A small table linking a company to sentiment score.

# %%
# Mock data
data = [
    {"Company": "MSFT", "Headline": "Microsoft announces major investment in solar and wind energy projects."},
    {"Company": "MSFT", "Headline": "Microsoft is accused by activist groups of underreporting Scope 3 emissions."},
    {"Company": "UL", "Headline": "Unilever recognized for its industry-leading sustainable sourcing program."},
    {"Company": "UL", "Headline": "Unilever faces backlash over controversial palm oil suppliers."},
    {"Company": "ORSTED.CO", "Headline": "Ørsted expands offshore wind farms to meet Europe’s green energy targets."},
    {"Company": "ORSTED.CO", "Headline": "Ørsted’s supply chain challenges raise questions on project timelines."}
]

df = pd.DataFrame(data)

# Compute sentiment polarity
def get_sentiment_polarity(text):
    analysis = TextBlob(text)
    return analysis.sentiment.polarity

df["Sentiment_Score"] = df["Headline"].apply(get_sentiment_polarity)

# Optionally, classify sentiment as Positive/Neutral/Negative based on polarity
def classify_sentiment(score):
    if score > 0.1:
        return "Positive"
    elif score < -0.1:
        return "Negative"
    else:
        return "Neutral"

df["Sentiment_Class"] = df["Sentiment_Score"].apply(classify_sentiment)

df
# Out:
#      Company                                           Headline  \
# 0       MSFT  Microsoft announces major investment in solar ...
# 1       MSFT  Microsoft is accused by activist groups of und...
# 2         UL  Unilever recognized for its industry-leading s...
# 3         UL  Unilever faces backlash over controversial pal...
# 4  ORSTED.CO  Ørsted expands offshore wind farms to meet Eur...
# 5  ORSTED.CO  Ørsted’s supply chain challenges raise questio...
#
#    Sentiment_Score Sentiment_Class
# 0           0.0625         Neutral
# 1           0.0000         Neutral
# 2           0.0000         Neutral
# 3           0.5500        Positive
# 4          -0.2000        Negative
# 5           0.0000         Neutral

# %% [markdown]
# 2. Data Exploration and Validation
# - Check Data Quality & Completeness:
#
#     Verify that each chosen company has entries in both the ESG and financial datasets.
#
#     Identify missing values or inconsistent data formats.

# %%
slug_to_ticker = {
    "orsted": "ORSTED.CO",                        # Ørsted (Copenhagen)
    "zurich-insurance": None,                    # Zurich Insurance Group (SIX: ZURN)
    "xano-industri": None,                      # XANO Industri AB (OMX: XANO-B)
    "wartsila": None,                           # Wärtsilä Oyj Abp (HEL: WRT1V)
    "wpp": "WPP",                               # WPP PLC (NYSE: WPP or LSE: WPP)
    "world-courier-sweden": None,
    "wihlborgs-fastigheter": None,              # Wihlborgs Fastigheter AB (OMX: WIHL)
    "westpac-banking": "WBC.AX",                # Westpac Banking Corp. (ASX: WBC)
    "wells-fargo": "WFC",                       # Wells Fargo & Company (NYSE: WFC)
    "walmart": "WMT",                           # Walmart Inc. (NYSE: WMT)
    "wallenstam": None,                         # Wallenstam AB (OMX: WALL-B)
    "volvo-car": "VOLCAR-B.ST",                 # Volvo Car AB (Nasdaq Stockholm: VOLCAR B)
    "volkswagen": "VOW.DE",                     # Volkswagen AG (Xetra: VOW)
    "volati": None,                             # Volati AB (OMX: VOLO)
    "vodafone": "VOD",                          # Vodafone Group PLC ADR (NASDAQ: VOD)
    "vnv-global": None,                         # VNV Global AB (OMX: VNV)
    "vitrolife": None,                          # Vitrolife AB (OMX: VITR)
    "vitol": None,                              # Vitol is private, no ticker
    "visa": "V",                                # Visa Inc. (NYSE: V)
    "vimian": None,                             # Vimian Group AB (OMX: VIMIAN)
    "viaplay": None,                            # Viaplay Group AB (OMX: VPLAY-B)
    "vestum": None,                             # Vestum AB (OMX: VESTUM)
    "vestas-wind-systems": None,                # Vestas Wind Systems A/S (CPH: VWS)
    "verizon-communications": "VZ",             # Verizon Communications (NYSE: VZ)
    "veidekke-entreprenad": None,               # Veidekke ASA (OSL: VEI)
    "vattenfall": None,                         # Vattenfall is state-owned, no ticker
    "vasakronan": None,                         # Vasakronan is owned by Swedish pension funds, no public ticker
    "valmet": "VALMT.HE",                       # Valmet Oyj (HEL: VALMT)
    "valero-energy": "VLO",                     # Valero Energy Corporation (NYSE: VLO)
    "upm-kymmene": None,                        # UPM-Kymmene Oyj (HEL: UPM)
    "unitedhealth": "UNH",                      # UnitedHealth Group (NYSE: UNH)
    "united-parcel-service": "UPS",             # United Parcel Service (NYSE: UPS)
    "uniper-se": None,                          # Uniper SE (Xetra: UN01) - now majority owned by the German government
    "union-pacific": "UNP",                     # Union Pacific Corporation (NYSE: UNP)
    "unilever": "UL",                           # Unilever PLC ADR (NYSE: UL)
    "unicredit": None,                          # UniCredit S.p.A. (BIT: UCG)
    "ubs": None,                                # UBS Group AG (NYSE: UBS or SIX: UBSG)
    "tuifly-nordic": None,                      # TUIfly Nordic is part of TUI AG (Xetra: TUI1)
    "tryg": None,                               # Tryg A/S (CPH: TRYG)
    "truist-financial": "TFC",                  # Truist Financial Corporation (NYSE: TFC)
    "travelers": "TRV",                         # The Travelers Companies (NYSE: TRV)
    "toyota-motor": "TM",                       # Toyota Motor Corp. ADR (NYSE: TM)
    "totalenergies-se": "TTE",                  # TotalEnergies SE (NYSE: TTE)
    "tokio-marine-holdings": None,              # Tokio Marine Holdings Inc. (TYO: 8766)
    "tobii-dynavox": None,                      # Tobii Dynavox AB (OMX: TODX)
    "tietoevry": None,                          # TietoEVRY Oyj (HEL: TIETO)
    "thule": None,                              # Thule Group AB (OMX: THULE)
    "thermo-fisher-scientific": "TMO",          # Thermo Fisher Scientific Inc. (NYSE: TMO)
    "walt-disney": "DIS",                       # The Walt Disney Company (NYSE: DIS)
    "kroger": "KR",                             # The Kroger Co. (NYSE: KR)
    "home-depot": "HD",                         # The Home Depot (NYSE: HD)
    "economist": None,                          # The Economist Group is private
    "coca-cola": "KO",                          # The Coca-Cola Company (NYSE: KO)
    "tesla": "TSLA",                            # Tesla Inc. (NASDAQ: TSLA)
    "tencent-holdings": "TCEHY",                # Tencent Holdings ADR (OTC: TCEHY)
    "telia": None,                              # Telia Company AB (OMX: TELIA)
    "telenor": None,                            # Telenor ASA (OSL: TEL)
    "telefonica": "TEF",                        # Telefónica S.A. (NYSE: TEF)
    "tele2": None,                              # Tele2 AB (OMX: TEL2-B)
    "technipfmc": "FTI",                        # TechnipFMC plc (NYSE: FTI)
    "td-bank": "TD",                            # The Toronto-Dominion Bank (NYSE: TD)
    "target": "TGT",                            # Target Corporation (NYSE: TGT)
    "takeda-pharmaceutical": "TAK",             # Takeda Pharmaceutical Co. Ltd. ADR (NYSE: TAK)
    "taiwan-semiconductor": "TSM",              # Taiwan Semiconductor Manufacturing Co. ADR (NYSE: TSM)
    "systemair": None,                          # Systemair AB (OMX: SYSR)
    "sydbank": None,                            # Sydbank A/S (CPH: SYDB)
    "swedish-orphan-biovitrum": None,           # Swedish Orphan Biovitrum AB (OMX: SOBI)
    "swedbank": None,                           # Swedbank AB (OMX: SWED-A)
    "svenska-handelsbanken-publ": None,          # Svenska Handelsbanken AB (OMX: SHB-A)
    "svedbergs": None,                          # Svedbergs i Dalstorp AB (OMX: SVED-B)
    "suncor-energy": "SU",                      # Suncor Energy Inc. (NYSE: SU)
    "sun-life-financial": "SLF",                # Sun Life Financial Inc. (NYSE: SLF)
    "sumitomo-mitsui-financial": None,          # Sumitomo Mitsui Financial Group Inc. (NYSE: SMFG)
    "strawberry": None,                         # Strawberry is likely private
    "storytel": None,                           # Storytel AB (OMX: STORY-B)
    "storskogen": None,                         # Storskogen Group AB (publ) (OMX: STOR-B)
    "stora-enso": None,                         # Stora Enso Oyj (HEL: STERV)
    "stillfront": None,                         # Stillfront Group AB (OMX: SF)
    "stena-recycling": None,                    # Stena Recycling is private
    "stellantis": "STLA",                       # Stellantis N.V. (NYSE: STLA)
    "state-bank-of-india": "SBIN.NS",           # State Bank of India (NSE: SBIN)
    "ssab": None,                               # SSAB AB (OMX: SSAB-A)
    "spendrups-bryggeri": None,                 # Spendrups privately held
    "specialfastigheter-sverige": None,         # Specialfastigheter Sverige AB is state-owned, no ticker
    "southern": "SO",                           # The Southern Company (NYSE: SO)
    "sony": "SONY",                             # Sony Group Corp. ADR (NYSE: SONY)
    "softbank": "SFTBY",                        # SoftBank Group Corp. ADR (OTC: SFTBY)
    "sky": None,                                # Sky Group is owned by Comcast (NASDAQ: CMCSA)
    "skistar": None,                            # Skistar AB (OMX: SKIS-B)
    "skanska": None,                            # Skanska AB (OMX: SKA-B)
    "sk-hynix": None,                           # SK hynix Inc. (KRX: 000660)
    "sinopec": "SNP",                           # China Petroleum & Chemical Corp. ADR (NYSE: SNP)
    "siemens": None,                            # Siemens AG (Xetra: SIE)
    "shinhan-financial": "SHG",                 # Shinhan Financial Group Co. Ltd. ADR (NYSE: SHG)
    "shell": "SHEL",                            # Shell plc (NYSE: SHEL)
    "seven-and-i-holdings": None,               # Seven & i Holdings Co. Ltd. (TYO: 3382)
    "serneke": None,                            # Serneke Group AB (OMX: SRNKE-B)
    "seenthis": None,                           # SeenThis AB is private
    "securitas": None                           # Securitas AB (OMX: SECU-B)
}

# %%
# Add a ticker column to ESG data based on the slug
companies_df['Ticker'] = companies_df['slug'].map(slug_to_ticker)

# %%
merge_df = pd.merge(companies_df, financial_df, on='Ticker', how='inner')

# %%
# Checking data quality & completeness once keys are matched:
# Companies that are in both dataframes
esg_tickers = set(companies_df['Ticker'].dropna())
fin_tickers = set(financial_df['Ticker'].dropna())

common_tickers = esg_tickers.intersection(fin_tickers)
print("Companies in both ESG and Financial datasets:", common_tickers)

only_in_esg = esg_tickers - fin_tickers
print("Companies only in ESG data:", only_in_esg)

only_in_fin = fin_tickers - esg_tickers
print("Companies only in Financial data:", only_in_fin)
# Out:
# Companies in both ESG and Financial datasets: {'ORSTED.CO', 'UL'}
# Companies only in ESG data: {'SHEL', 'TM', 'VALMT.HE', 'TFC', 'TSM', 'VZ', 'VOLCAR-B.ST', 'DIS', 'SONY', 'VOD', 'UPS', 'TSLA', 'UNH', 'TAK', 'TCEHY', 'SHG', 'SNP', 'TD', 'FTI', 'TTE', 'WBC.AX', 'VLO', 'STLA', 'KO', 'KR', 'HD', 'WPP', 'SFTBY', 'WFC', 'SO', 'TRV', 'V', 'TMO', 'SBIN.NS', 'VOW.DE', 'UNP', 'WMT', 'TEF', 'SU', 'TGT', 'SLF'}
# Companies only in Financial data: {'MSFT'}

# %%
# For missing values:
print("ESG Missing Values:\n", companies_df.isna().sum())
print("Financial Missing Values:\n", financial_df.isna().sum())
# Out:
# ESG Missing Values:
#  company_name                            0
# slug                                    0
# company_url                            76
# industry                               39
# organization_type                      41
# tags                                   80
# commitment_type                        54
# status                                 54
# commitment_deadline                    54
# total_reported_emission_scope_1_2_3     0
# revenue                                 5
# hq_country                             39
# year                                    0
# currency                                0
# emission_intensity                      5
# Ticker                                 56
# dtype: int64
# Financial Missing Values:
#  Ticker           0
# ShortName        0
# MarketCap        0
# PE_Ratio         0
# ForwardPE        0
# DividendYield    1
# Sector           0
# Industry         0
# dtype: int64

# %%
#Check data types:
print("ESG dtypes:\n", companies_df.dtypes)
print("Financial dtypes:\n", financial_df.dtypes)
# Out:
# ESG dtypes:
#  company_name                            object
# slug                                    object
# company_url                             object
# industry                                object
# organization_type                       object
# tags                                    object
# commitment_type                         object
# status                                  object
# commitment_deadline                     object
# total_reported_emission_scope_1_2_3      int64
# revenue                                float64
# hq_country                              object
# year                                     int64
# currency                                object
# emission_intensity                     float64
# Ticker                                  object
# dtype: object
# Financial dtypes:
#  Ticker            object
# ShortName         object
# MarketCap          int64
# PE_Ratio         float64
# ForwardPE        float64
# DividendYield    float64
# Sector            object
# Industry          object
# dtype: object
